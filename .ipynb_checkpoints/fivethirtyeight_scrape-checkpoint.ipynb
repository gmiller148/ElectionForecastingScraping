# %%
import requests
from bs4 import BeautifulSoup
import json
import numpy as np
from pypfopt.efficient_frontier import EfficientFrontier

# %%
resp = requests.get('https://projects.fivethirtyeight.com/2020-election-forecast/arizona/',headers={"content-type":"text"})

# %%
soup = BeautifulSoup(resp.text,'html.parser')

# %%
state_list = []
for l in soup.find_all('select',class_='state-dropdown'):
    for option in l.find_all('option'):
        state_list.append(option.text)
state_list = state_list[1:]

# %%
state_list = [state.replace(' ', '-').lower() for state in state_list]

# %%
state_list = [state[:-11] if 'district' in state[-11:] else state for state in state_list]

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="2020-10-24T13:21:23-04:00" property="article:modified_time"/>
#   <title>
#    2020 Election Forecast | FiveThirtyEight
#   </title>
#   <meta content="2020 Election Forecast" property="og:title"/>
#   <meta content="Latest forecast of the 2020 presidential election between President Donald Trump and Joe Biden by Nate Silver’s FiveThirtyEight" property="og:description"/>
#   <meta content="Latest forecast of the 2020 presidential election between President Donald Trump and Joe Biden by Nate Silver’s FiveThirtyEight" name="description"/>
#   <link href="https://projects.fivethirtyeight.com/2020-election-forecast/" rel="canonical"/>
#   <meta content="https://projects.fivethirtyeight.com/2020-election-forecast/" property="og:url"/>
#   <meta content="https://fivethirtyeight.com/wp-content/uploads/2020/08/2020-FTE-PresPromo-16x9-sized.jpg" property="og:image"/>
#   <meta content="https://fivethirtyeight.com/wp-content/uploads/2020/08/2020-FTE-PresPromo-16x9-sized.jpg" name="twitter:image:src"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="article" property="og:type"/>
#   <meta content="FiveThirtyEight" property="og:site_name"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="2020-08-12T06:30:00-04:00" property="article:published_time"/>
#   <meta content="https://www.facebook.com/FiveThirtyEight" property="article:publisher"/>
#   <meta content="https://fivethirtyeight.com/contributors/nate-silver/" property="article:author"/>
#   <meta content="797620670264818" property="fb:app_id"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="FiveThirtyEight" name="application-name"/>
#   <meta content="Nate Silver" name="author"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="on" name="twitter:widgets:csp"/>
#   <meta content="300" name="twitter:maxage"/>
#   <meta content="FiveThirtyEight" name="twitter:site"/>
#   <meta content="2303751216" name="twitter:site:id"/>
#   <meta content="NateSilver538" name="twitter:creator"/>
#   <meta content="16017475" name="twitter:creator:id"/>
#   <link href="https://fivethirtyeight.com/contributors/nate-silver/" rel="author"/>
#   <link href="https://fivethirtyeight.com/osd.xml" rel="search" title="FiveThirtyEight" type="application/opensearchdescription+xml"/>
#   <link href="https://wordpress.com/opensearch.xml" rel="search" title="WordPress.com" type="application/opensearchdescription+xml"/>
#   <link href="https://projects.fivethirtyeight.com/shared/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://projects.fivethirtyeight.com/shared/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="https://projects.fivethirtyeight.com/shared/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <link color="#ed713a" href="https://projects.fivethirtyeight.com/shared/safari-pinned-tab.svg" rel="mask-icon"/>
#   <link href="fivethirtyeight.com" rel="dns-prefetch"/>
#   <link href="secure.espn.com" rel="dns-prefetch"/>
#   <link href="s.abcnews.com" rel="dns-prefetch"/>
#   <script>
#    var trackingConfig = {
#         postId: "277084",
#         section: "politics",
#         primaryTag: "politics",
#         pageName: "2020-general-forecast",
#         title: "2020 Election Forecast",
#         author: "Nate Silver",
#         authorSlug: "silver_nate",
#         fullUrl: "https://projects.fivethirtyeight.com/2020-election-forecast/",
#         path: "2020-election-forecast/",
#         twitterText: "Who will win the 2020 election? FiveThirtyEight's latest presidential forecast: ",
#         publishTime: "2020-08-12 06:30"
#       };
#   </script>
#   <link href="/2020-election-forecast/css/app.css?v=05429d48f8b07b88f6aa" rel="stylesheet"/>
#   <script>
#    var staticUrl = '/2020-election-forecast';
#       var imageCache = {"FTE-2020-Wordmark-dark.svg":"8ff75ca7","FTE-2020-Wordmark.svg":"999c3e3a","FTE-Logotype.svg":"ef70c32c","GF-background-noshadow.svg":"77265f2d","GF-background.svg":"e36aa3af","SNAKE4RYAN.svg":"40467310","SNAKE4RYAN_MOB.svg":"9a09cc69","SNAKE4RYAN_STATERECIRC.svg":"5ce49f85","SNAKE4RYAN_UNROTATED.svg":"0b5e6eb6","biden-head-original.png":"48da5e42","biden-head.png":"26c42f51","carrot-usa.svg":"8a4c84fb","clippy.png":"d9ae5d9a","incumbent-legend.svg":"0d98ca09","model-picker-shadow-text.png":"5aa54591","model-picker-shadow.png":"19032535","model-picker.png":"10faab40","pencil-logo.svg":"424529a3","race-list-joint-legend.svg":"43666e53","resize-heads.sh":"1d58daf7","senate-icon-legend.svg":"d7fffcc5","snake-legend.svg":"4ec6d888","special-star.svg":"e63c2656","state-senate-legend.svg":"0bd629ae","trump-head-original.png":"6f277d56","trump-head.png":"ae1cfe3b","fivey/calculator.png":"cd14c137","fivey/flag.png":"760da13d","fivey/foam-finger.png":"b6fa5ec8","fivey/grad-jump.png":"106ae9ec","fivey/jar.png":"c0452b38","fivey/jumping.png":"159c60ae","fivey/pennant.png":"369b22ea","fivey/picker.png":"fc91063f","fivey/podcast.png":"d9107bf0","fivey/professor-flipped.png":"dda27466","fivey/professor.png":"08fb7e86","fivey/sad.png":"bb2f8d80","fivey/shrugging-flipped.png":"b5fcc636","fivey/shrugging.png":"9340523f","fivey/skeptical.png":"5746f9a1","fivey/sleepy.png":"7369e581","fivey/standing.png":"ab83fe0d","fivey/star-struck.png":"169db5e1","fivey/stop-sign.png":"20e17490","fivey/stressed.png":"8cd75821","fivey/thumbs-down.png":"1c5d6217","fivey/thumbs-up.png":"557805e6","fivey/waving.png":"f51cfe83","fivey/writing.png":"1fccf391"};
#   </script>
#   <script defer="defer" src="/2020-election-forecast/js/bundle.js?v=63c7d87d8e8012828217">
#   </script>
#  </head>
#  <body>
#   <header class="page-header vertical-politics">
#    <div class="header-wrapper">
#     <div class="header-chamber chamber-nav hide-mobile">
#      <div class="chamber-link-cont desktop president" data-chamber="president">
#       P
#       <div class="chamber-tooltip president">
#        Click here to see the presidential forecast
#       </div>
#      </div>
#      <div class="chamber-link-cont desktop senate" data-chamber="senate">
#       S
#       <div class="chamber-tooltip senate">
#        Click here to see the Senate forecast
#       </div>
#      </div>
#      <div class="chamber-link-cont desktop house" data-chamber="house">
#       H
#       <div class="chamber-tooltip house">
#        Click here to see the House forecast
#       </div>
#      </div>
#     </div>
#     <div class="header-nav">
#      <div class="header-state-select">
#       <select aria-label="select a state">
#        <option value="US">
#        </option>
#        <optgroup label="States to watch">
#         <option selected="selected" value="AZ">
#         </option>
#         <option value="CO">
#         </option>
#         <option value="FL">
#         </option>
#         <option value="GA">
#         </option>
#         <option value="IA">
#         </option>
#         <option value="ME">
#         </option>
#         <option value="MI">
#         </option>
#         <option value="MN">
#         </option>
#         <option value="NV">
#         </option>
#         <option value="NH">
#         </option>
#         <option value="NM">
#         </option>
#         <option value="NC">
#         </option>
#         <option value="OH">
#         </option>
#         <option value="PA">
#         </option>
#         <option value="VA">
#         </option>
#         <option value="WI">
#         </option>
#        </optgroup>
#        <optgroup label="All states">
#         <option value="AL">
#         </option>
#         <option value="AK">
#         </option>
#         <option value="AZ">
#         </option>
#         <option value="AR">
#         </option>
#         <option value="CA">
#         </option>
#         <option value="CO">
#         </option>
#         <option value="CT">
#         </option>
#         <option value="DE">
#         </option>
#         <option value="DC">
#         </option>
#         <option value="FL">
#         </option>
#         <option value="GA">
#         </option>
#         <option value="HI">
#         </option>
#         <option value="ID">
#         </option>
#         <option value="IL">
#         </option>
#         <option value="IN">
#         </option>
#         <option value="IA">
#         </option>
#         <option value="KS">
#         </option>
#         <option value="KY">
#         </option>
#         <option value="LA">
#         </option>
#         <option value="ME">
#         </option>
#         <option value="ME1">
#         </option>
#         <option value="ME2">
#         </option>
#         <option value="MD">
#         </option>
#         <option value="MA">
#         </option>
#         <option value="MI">
#         </option>
#         <option value="MN">
#         </option>
#         <option value="MS">
#         </option>
#         <option value="MO">
#         </option>
#         <option value="MT">
#         </option>
#         <option value="NE">
#         </option>
#         <option value="NE1">
#         </option>
#         <option value="NE2">
#         </option>
#         <option value="NE3">
#         </option>
#         <option value="NV">
#         </option>
#         <option value="NH">
#         </option>
#         <option value="NJ">
#         </option>
#         <option value="NM">
#         </option>
#         <option value="NY">
#         </option>
#         <option value="NC">
#         </option>
#         <option value="ND">
#         </option>
#         <option value="OH">
#         </option>
#         <option value="OK">
#         </option>
#         <option value="OR">
#         </option>
#         <option value="PA">
#         </option>
#         <option value="RI">
#         </option>
#         <option value="SC">
#         </option>
#         <option value="SD">
#         </option>
#         <option value="TN">
#         </option>
#         <option value="TX">
#         </option>
#         <option value="UT">
#         </option>
#         <option value="VT">
#         </option>
#         <option value="VA">
#         </option>
#         <option value="WA">
#         </option>
#         <option value="WV">
#         </option>
#         <option value="WI">
#         </option>
#         <option value="WY">
#         </option>
#        </optgroup>
#       </select>
#      </div>
#      <div class="header-race-search">
#       <input placeholder="Find a race" type="search"/>
#       <div class="btn-clear js-btn-clear hidden">
#        <p>
#         +
#        </p>
#       </div>
#      </div>
#     </div>
#     <div class="header-logo">
#      <a class="logo" href="https://fivethirtyeight.com">
#       <img alt="FiveThirtyEight" src="/2020-election-forecast/images/FTE-2020-Wordmark.svg?v=999c3e3a"/>
#      </a>
#     </div>
#    </div>
#    <div class="ad" id="sponsorship-desktop">
#    </div>
#   </header>
#   <div id="header-spacer">
#   </div>
#   <div class="ad" id="sponsorship-mobile">
#   </div>
#   <div class="ad" id="ad-0">
#   </div>
#   <div class="lede-wrap hidden">
#   </div>
#   <div class="container">
#    <div class="national-nav module-fivey-cont visible" id="back-text">
#     <div class="back-link-container" href="president">
#      <div class="fivey-wrap flag national-link center">
#       <div class="fivey flag national-link center">
#       </div>
#       <div class="fivey-text flag national-link center">
#        Looking for the national forecast? Click me!
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="page-body">
#     <div class="timestamp-container">
#      <p class="timestamp" id="js-timestamp">
#      </p>
#     </div>
#     <div class="module-fivey-cont" id="topline-module-fivey-cont">
#      <div class="module border-gradient viz-module" id="topline">
#       <h2>
#       </h2>
#       <p class="intro">
#        We simulate the election 40,000 times to see who wins most often. The sample of 100 outcomes below gives you a good idea of the range of scenarios our model thinks is possible.
#       </p>
#       <div class="chart-tooltip-container" id="topline-chart-tooltip">
#        <div class="chart-container" id="topline-chart">
#        </div>
#        <div class="tooltip-container" id="topline-tooltip-container">
#         <div class="tooltip" id="topline-tooltip">
#          <div class="tooltip-chart-container" id="topline-tooltip-map">
#          </div>
#          <div class="tooltip-content">
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="legend-wrap">
#        <div class="legend-container state">
#         <div class="candidate">
#          <div class="dot state trump">
#          </div>
#          <div class="legend-label" id="rep-label">
#          </div>
#         </div>
#         <div class="candidate">
#          <div class="dot state biden">
#          </div>
#          <div class="legend-label" id="dem-label">
#          </div>
#         </div>
#        </div>
#        <div class="legend-container runoff hidden" id="runoff-legend-container">
#         <div class="legend-label" id="runoff-label">
#          <span>
#           *
#          </span>
#          Seat won in a runoff
#         </div>
#        </div>
#        <div class="legend-container runoff-leader hidden" id="runoff-leader-legend-container">
#         <div class="legend-label" id="runoff-leader-label">
#         </div>
#        </div>
#       </div>
#       <div class="footnote statewide-footnote hidden" id="statewide-footnote">
#       </div>
#       <div class="footnote runoff-footnote hidden" id="runoff-footnote">
#       </div>
#       <div class="footnote mn-footnote hidden" id="mn-footnote">
#       </div>
#      </div>
#     </div>
#     <div class="module state-chamber-nav" id="state-chamber-nav">
#      <div class="state-chamber-nav-container">
#      </div>
#     </div>
#     <div class="module-fivey-cont">
#      <div class="module border-gradient viz-module" id="change">
#       <h2>
#        How the forecast has changed
#       </h2>
#       <p>
#        The forecast updates at least once a day and whenever we get a new poll. Click the buttons to see the ways each candidate’s outlook has changed over time.
#       </p>
#       <div class="btn-container">
#        <button class="btn-cta btn-change border-gradient active" id="winprob">
#         Chance of winning
#        </button>
#        <button class="btn-cta btn-change border-gradient" id="voteshare">
#         Popular vote
#        </button>
#       </div>
#       <div class="btn-container btn-container-mobile">
#        <button class="btn-cta btn-change border-gradient active" id="winprob">
#         Win chance
#        </button>
#        <button class="btn-cta btn-change border-gradient" id="voteshare">
#         Pop. vote
#        </button>
#       </div>
#       <div class="chart-container" id="change-chart">
#       </div>
#      </div>
#     </div>
#     <div class="module latest-polls lazy-load-hide" id="latest-polls">
#      <h2 class="lead">
#       Which polls are influencing the forecast for Arizona?
#      </h2>
#      <p class="polls-dek">
#      </p>
#      <table class="president">
#       <thead class="d">
#        <tr>
#         <th class="pollster">
#          Pollster
#         </th>
#         <th class="rating">
#          Rating
#         </th>
#         <th class="dates">
#         </th>
#        </tr>
#       </thead>
#       <tbody class="d">
#       </tbody>
#       <thead class="m">
#        <tr>
#         <th class="pollster">
#          Pollster
#         </th>
#         <th class="leader">
#          Leader
#         </th>
#        </tr>
#       </thead>
#       <tbody class="m">
#       </tbody>
#      </table>
#      <div class="polls-link">
#       <a href="https://projects.fivethirtyeight.com/polls/">
#       </a>
#       <img aria-hidden="true" src="/2020-election-forecast/images/carrot-usa.svg?v=8a4c84fb"/>
#      </div>
#     </div>
#     <div class="module viz-module" id="polls-to-forecast">
#      <h2>
#       How do we get from polls to forecasted vote share?
#      </h2>
#      <p class="dek">
#      </p>
#      <table>
#       <thead>
#        <tr>
#         <th class="step">
#         </th>
#         <th class="description">
#         </th>
#        </tr>
#       </thead>
#       <tbody>
#       </tbody>
#      </table>
#     </div>
#     <div class="module-fivey-cont">
#      <div class="module border-gradient state-recirc" id="state-recirc">
#       <h2>
#        <select aria-label="change visible state links" class="metric-dropdown" id="state-recirc-metric-dropdown">
#         <option value="margin">
#          See states with the closest races
#         </option>
#         <option value="tipping">
#          See states close to the tipping point
#         </option>
#        </select>
#       </h2>
#       <div class="recirc-container" id="state-recirc-container">
#       </div>
#       <div>
#        <select aria-label=" " class="state-dropdown" id="state-recirc-state-dropdown">
#         <option>
#          Or choose another state
#         </option>
#         <option value="alabama">
#          Alabama
#         </option>
#         <option value="alaska">
#          Alaska
#         </option>
#         <option value="arkansas">
#          Arkansas
#         </option>
#         <option value="california">
#          California
#         </option>
#         <option value="colorado">
#          Colorado
#         </option>
#         <option value="connecticut">
#          Connecticut
#         </option>
#         <option value="delaware">
#          Delaware
#         </option>
#         <option value="district-of-columbia">
#          District of Columbia
#         </option>
#         <option value="florida">
#          Florida
#         </option>
#         <option value="georgia">
#          Georgia
#         </option>
#         <option value="hawaii">
#          Hawaii
#         </option>
#         <option value="idaho">
#          Idaho
#         </option>
#         <option value="illinois">
#          Illinois
#         </option>
#         <option value="indiana">
#          Indiana
#         </option>
#         <option value="iowa">
#          Iowa
#         </option>
#         <option value="kansas">
#          Kansas
#         </option>
#         <option value="kentucky">
#          Kentucky
#         </option>
#         <option value="louisiana">
#          Louisiana
#         </option>
#         <option value="maine">
#          Maine
#         </option>
#         <option value="maine-1">
#          Maine 1st District
#         </option>
#         <option value="maine-2">
#          Maine 2nd District
#         </option>
#         <option value="maryland">
#          Maryland
#         </option>
#         <option value="massachusetts">
#          Massachusetts
#         </option>
#         <option value="michigan">
#          Michigan
#         </option>
#         <option value="minnesota">
#          Minnesota
#         </option>
#         <option value="mississippi">
#          Mississippi
#         </option>
#         <option value="missouri">
#          Missouri
#         </option>
#         <option value="montana">
#          Montana
#         </option>
#         <option value="nebraska">
#          Nebraska
#         </option>
#         <option value="nebraska-1">
#          Nebraska 1st District
#         </option>
#         <option value="nebraska-2">
#          Nebraska 2nd District
#         </option>
#         <option value="nebraska-3">
#          Nebraska 3rd District
#         </option>
#         <option value="nevada">
#          Nevada
#         </option>
#         <option value="new-hampshire">
#          New Hampshire
#         </option>
#         <option value="new-jersey">
#          New Jersey
#         </option>
#         <option value="new-mexico">
#          New Mexico
#         </option>
#         <option value="new-york">
#          New York
#         </option>
#         <option value="north-carolina">
#          North Carolina
#         </option>
#         <option value="north-dakota">
#          North Dakota
#         </option>
#         <option value="ohio">
#          Ohio
#         </option>
#         <option value="oklahoma">
#          Oklahoma
#         </option>
#         <option value="oregon">
#          Oregon
#         </option>
#         <option value="pennsylvania">
#          Pennsylvania
#         </option>
#         <option value="rhode-island">
#          Rhode Island
#         </option>
#         <option value="south-carolina">
#          South Carolina
#         </option>
#         <option value="south-dakota">
#          South Dakota
#         </option>
#         <option value="tennessee">
#          Tennessee
#         </option>
#         <option value="texas">
#          Texas
#         </option>
#         <option value="utah">
#          Utah
#         </option>
#         <option value="vermont">
#          Vermont
#         </option>
#         <option value="virginia">
#          Virginia
#         </option>
#         <option value="washington">
#          Washington
#         </option>
#         <option value="west-virginia">
#          West Virginia
#         </option>
#         <option value="wisconsin">
#          Wisconsin
#         </option>
#         <option value="wyoming">
#          Wyoming
#         </option>
#        </select>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="page-header bottom show-mobile">
#     <div class="header-chamber chamber-nav show-mobile">
#      <div class="chamber-link-cont mobile president" data-chamber="president">
#       <div class="black-bar">
#       </div>
#       Presidential
#      </div>
#      <div class="chamber-link-cont mobile senate" data-chamber="senate">
#       <div class="black-bar">
#       </div>
#       Senate
#      </div>
#      <div class="chamber-link-cont mobile house" data-chamber="house">
#       <div class="black-bar">
#       </div>
#       House
#      </div>
#     </div>
#    </div>
#   </div>
#   <script>
#    var interactivePage = {};
#       interactivePage.stateSlug = "arizona";
#       interactivePage.chamber = "president";
#       interactivePage.metadata = {"president":{"metaTitle":"2020 Election Forecast","metaDescription":"Latest forecast of the 2020 presidential election between President Donald Trump and Joe Biden by Nate Silver’s FiveThirtyEight","metaCanonicalUrl":"https://projects.fivethirtyeight.com/2020-election-forecast/","metaImage":"https://fivethirtyeight.com/wp-content/uploads/2020/08/2020-FTE-PresPromo-16x9-sized.jpg"},"senate":{"metaTitle":"2020 Senate Election Forecast","metaDescription":"Latest forecasts and polls for the 2020 Senate elections by Nate Silver’s FiveThirtyEight","metaCanonicalUrl":"https://projects.fivethirtyeight.com/2020-election-forecast/senate/","metaImage":"https://fivethirtyeight.com/wp-content/uploads/2020/09/FTE-SenatePromo-16x9-1.png"},"house":{"metaTitle":"2020 House Forecast","metaDescription":"Latest forecasts and polls for the 2020 House elections by Nate Silver’s FiveThirtyEight","metaCanonicalUrl":"https://projects.fivethirtyeight.com/2020-election-forecast/house/","metaImage":"https://fivethirtyeight.com/wp-content/uploads/2020/10/FTE-HousePromo-16x9-1.png"}};
#   </script>
#   <div class="container">
#    <div id="footer">
#     <p class="notes">
#      <span class="readin">
#      </span>
#      <span class="description">
#      </span>
#     </p>
#     <div class="additional-credits">
#      <p>
#      </p>
#     </div>
#     <div class="sources">
#      <p>
#      </p>
#     </div>
#    </div>
#   </div>
#   <div class="container clearfix" id="related" style="display:none">
#    <h3 class="subhead-fte-module">
#     Related Stories
#    </h3>
#    <div class="related one" id="related-1">
#    </div>
#    <div class="related two" id="related-2">
#    </div>
#    <div class="related three" id="related-3">
#    </div>
#    <div class="related four" id="related-4">
#    </div>
#    <div class="related five" id="related-5">
#    </div>
#   </div>
#   <div class="comments fte-expandable container">
#    <h3 class="subhead-fte-module subhed-fte-comments" id="fte-expandable-title">
#     Comments
#     <span class="fte-expandable-icon">
#     </span>
#    </h3>
#    <div class="entry-comments-content fte-expandable-content" id="entry-comments-content" style="display: none">
#     <div class="fb-comments fb_iframe_widget" data-colorscheme="light" data-href="https://projects.fivethirtyeight.com/2020-election-forecast/" data-numposts="5" data-order-by="reverse_time" data-width="100%" id="fb-comments">
#     </div>
#    </div>
#   </div>
#   <div class="site-footer js" id="colophon">
#    <div class="site-wrapper footer-main-content">
#     <div class="footer-section-get-more">
#      Get more FiveThirtyEight
#     </div>
#     <div class="footer-section-primary-links">
#      <ul class="footer-menu">
#       <li class="footer-menu-item">
#        <a href="https://fivethirtyeight.com/newsletter/">
#         Newsletter
#        </a>
#       </li>
#       <li class="footer-menu-item">
#        <a href="https://fivethirtyeight.com/videos/">
#         Videos
#        </a>
#       </li>
#       <li class="footer-menu-item">
#        <a href="https://fivethirtyeight.com/tag/fivethirtyeight-podcasts/">
#         Podcasts
#        </a>
#       </li>
#       <li class="footer-menu-item">
#        <a href="https://twitter.com/fivethirtyeight">
#         Twitter
#        </a>
#       </li>
#       <li class="footer-menu-item">
#        <a href="https://www.facebook.com/fivethirtyeight">
#         Facebook
#        </a>
#       </li>
#       <li class="footer-menu-item">
#        <a href="https://data.fivethirtyeight.com/">
#         Data
#        </a>
#       </li>
#       <li class="footer-menu-item">
#        <a href="https://fivethirtyeight.com/datalab/fear-not-readers-we-have-rss-feeds/">
#         RSS
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="footer-section-secondary-links">
#      <ul class="footer-menu">
#       <li class="footer-menu-item">
#        <a href="https://fivethirtyeight.com/contact/">
#         Contact
#        </a>
#       </li>
#       <li class="footer-menu-item">
#        <a href="https://fivethirtyeight.com/jobs/">
#         Jobs
#        </a>
#       </li>
#       <li class="footer-menu-item">
#        <a href="https://fivethirtyeight.com/masthead/">
#         Masthead
#        </a>
#       </li>
#       <li class="footer-menu-item">
#        <a href="http://priv-policy.imrworldwide.com/priv/browser/us/en/optout.html">
#         About Nielsen Measurement
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="footer-section-tertiary-links">
#      <ul class="footer-menu">
#       <li class="footer-menu-item">
#        <a href="https://disneytermsofuse.com/" rel="noopener noreferrer" target="_blank">
#         Terms of Use
#        </a>
#       </li>
#       <li class="footer-menu-item">
#        <a href="https://disneyprivacycenter.com/" rel="noopener noreferrer" target="_blank">
#         Privacy Policy
#        </a>
#       </li>
#       <li class="footer-menu-item">
#        <a href="https://privacy.thewaltdisneycompany.com/en/dnsmi/" rel="noopener noreferrer" target="_blank">
#         Do Not Sell My Info
#        </a>
#       </li>
#       <li class="footer-menu-item">
#        <a href="https://disneyprivacycenter.com/notice-to-california-residents/" rel="noopener noreferrer" target="_blank">
#         Your California Privacy Rights
#        </a>
#       </li>
#       <li class="footer-menu-item">
#        <a href="https://disneyprivacycenter.com/kids-privacy-policy/english/" rel="noopener noreferrer" target="_blank">
#         Children's Online Privacy Policy
#        </a>
#       </li>
#       <li class="footer-menu-item">
#        <a href="https://preferences-mgr.truste.com/?type=abcnews&amp;affiliateId=11&amp;cid=clicksource_4380645_footer_interestbasedads" rel="noopener noreferrer" target="_blank">
#         Interest-Based Ads
#        </a>
#       </li>
#      </ul>
#      <p>
#       © 2018 ABC News Internet Ventures. All rights reserved.
#      </p>
#     </div>
#    </div>
#   </div>
#   <script defer="defer" src="/bundled/js/bundled2.js">
#   </script>
#   <link href="/bundled/css/bundled2.css" rel="stylesheet"/>
#  </body>
# </html>

# %%
soup.find_all('text')
# Out:
# []

# %%
outcome = requests.get('https://projects.fivethirtyeight.com/2020-election-forecast/state_recirc.json')

# %%
election_prediction = json.loads(outcome.text)

# %%
state_by_state = election_prediction['president'][0]['states']

# %%
state_to_win_prob = {
    'state':[],
    'trump':[],
    'biden':[]
}
for state in state_by_state:
    if state['state'] not in ['NE1','NE2','NE3','ME1','ME2','DC']:
        state_to_win_prob['state'].append(state['state'])
        state_to_win_prob['trump'].append(state['candidates'][0]['winprob'])
        state_to_win_prob['biden'].append(state['candidates'][1]['winprob'])

# %%
import pandas as pd

# %%
df = pd.DataFrame(data=state_to_win_prob)

# %%
us_simulations = json.loads(requests.get('https://projects.fivethirtyeight.com/2020-election-forecast/us_simulations.json').text)

# %%
state_abbrev = sorted(list(df.state.unique()))

# %%
us_simulations[0]
# Out:
# {'type': 'polls-plus',
#  'simulations': [{'winner': 'Biden',
#    'evs': {'Biden': 375, 'Trump': 163},
#    'states': {'AK': {'state': 'AK', 'winner': 'Trump'},
#     'AL': {'state': 'AL', 'winner': 'Trump'},
#     'AR': {'state': 'AR', 'winner': 'Trump'},
#     'AZ': {'state': 'AZ', 'winner': 'Biden'},
#     'CA': {'state': 'CA', 'winner': 'Biden'},
#     'CO': {'state': 'CO', 'winner': 'Biden'},
#     'CT': {'state': 'CT', 'winner': 'Biden'},
#     'DC': {'state': 'DC', 'winner': 'Biden'},
#     'DE': {'state': 'DE', 'winner': 'Biden'},
#     'FL': {'state': 'FL', 'winner': 'Biden'},
#     'GA': {'state': 'GA', 'winner': 'Biden'},
#     'HI': {'state': 'HI', 'winner': 'Biden'},
#     'IA': {'state': 'IA', 'winner': 'Biden'},
#     'ID': {'state': 'ID', 'winner': 'Trump'},
#     'IL': {'state': 'IL', 'winner': 'Biden'},
#     'IN': {'state': 'IN', 'winner': 'Trump'},
#     'KS': {'state': 'KS', 'winner': 'Trump'},
#     'KY': {'state': 'KY', 'winner': 'Trump'},
#     'LA': {'state': 'LA', 'winner': 'Trump'},
#     'MA': {'state': 'MA', 'winner': 'Biden'},
#     'MD': {'state': 'MD', 'winner': 'Biden'},
#     'ME': {'state': 'ME', 'winner': 'Biden'},
#     'ME1': {'state': 'ME1', 'winner': 'Biden'},
#     'ME2': {'state': 'ME2', 'winner': 'Biden'},
#     'MI': {'state': 'MI', 'winner': 'Biden'},
#     'MN': {'state': 'MN', 'winner': 'Biden'},
#     'MO': {'state': 'MO', 'winner': 'Trump'},
#     'MS': {'state': 'MS', 'winner': 'Trump'},
#     'MT': {'state': 'MT', 'winner': 'Trump'},
#     'NC': {'state': 'NC', 'winner': 'Biden'},
#     'ND': {'state': 'ND', 'winner': 'Trump'},
#     'NE': {'state': 'NE', 'winner': 'Trump'},
#     'NE1': {'state': 'NE1', 'winner': 'Trump'},
#     'NE2': {'state': 'NE2', 'winner': 'Biden'},
#     'NE3': {'state': 'NE3', 'winner': 'Trump'},
#     'NH': {'state': 'NH', 'winner': 'Biden'},
#     'NJ': {'state': 'NJ', 'winner': 'Biden'},
#     'NM': {'state': 'NM', 'winner': 'Biden'},
#     'NV': {'state': 'NV', 'winner': 'Biden'},
#     'NY': {'state': 'NY', 'winner': 'Biden'},
#     'OH': {'state': 'OH', 'winner': 'Biden'},
#     'OK': {'state': 'OK', 'winner': 'Trump'},
#     'OR': {'state': 'OR', 'winner': 'Biden'},
#     'PA': {'state': 'PA', 'winner': 'Biden'},
#     'RI': {'state': 'RI', 'winner': 'Biden'},
#     'SC': {'state': 'SC', 'winner': 'Trump'},
#     'SD': {'state': 'SD', 'winner': 'Trump'},
#     'TN': {'state': 'TN', 'winner': 'Trump'},
#     'TX': {'state': 'TX', 'winner': 'Trump'},
#     'UT': {'state': 'UT', 'winner': 'Trump'},
#     'VA': {'state': 'VA', 'winner': 'Biden'},
#     'VT': {'state': 'VT', 'winner': 'Biden'},
#     'WA': {'state': 'WA', 'winner': 'Biden'},
#     'WI': {'state': 'WI', 'winner': 'Biden'},
#     'WV': {'state': 'WV', 'winner': 'Trump'},
#     'WY': {'state': 'WY', 'winner': 'Trump'}}},
#   {'winner': 'Biden',
#    'evs': {'Biden': 375, 'Trump': 163},
#    'states': {'AK': {'state': 'AK', 'winner': 'Trump'},
#     'AL': {'state': 'AL', 'winner': 'Trump'},
#     'AR': {'state': 'AR', 'winner': 'Trump'},
#     'AZ': {'state': 'AZ', 'winner': 'Biden'},
#     'CA': {'state': 'CA', 'winner': 'Biden'},
#     'CO': {'state': 'CO', 'winner': 'Biden'},
#     'CT': {'state': 'CT', 'winner': 'Biden'},
#     'DC': {'state': 'DC', 'winner': 'Biden'},
#     'DE': {'state': 'DE', 'winner': 'Biden'},
#     'FL': {'state': 'FL', 'winner': 'Biden'},
#     'GA': {'state': 'GA', 'winner': 'Biden'},
#     'HI': {'state': 'HI', 'winner': 'Biden'},
#     'IA': {'state': 'IA', 'winner': 'Biden'},
#     'ID': {'state': 'ID', 'winner': 'Trump'},
#     'IL': {'state': 'IL', 'winner': 'Biden'},
#     'IN': {'state': 'IN', 'winner': 'Trump'},
#     'KS': {'state': 'KS', 'winner': 'Trump'},
#     'KY': {'state': 'KY', 'winner': 'Trump'},
#     'LA': {'state': 'LA', 'winner': 'Trump'},
#     'MA': {'state': 'MA', 'winner': 'Biden'},
#     'MD': {'state': 'MD', 'winner': 'Biden'},
#     'ME': {'state': 'ME', 'winner': 'Biden'},
#     'ME1': {'state': 'ME1', 'winner': 'Biden'},
#     'ME2': {'state': 'ME2', 'winner': 'Biden'},
#     'MI': {'state': 'MI', 'winner': 'Biden'},
#     'MN': {'state': 'MN', 'winner': 'Biden'},
#     'MO': {'state': 'MO', 'winner': 'Trump'},
#     'MS': {'state': 'MS', 'winner': 'Trump'},
#     'MT': {'state': 'MT', 'winner': 'Trump'},
#     'NC': {'state': 'NC', 'winner': 'Biden'},
#     'ND': {'state': 'ND', 'winner': 'Trump'},
#     'NE': {'state': 'NE', 'winner': 'Trump'},
#     'NE1': {'state': 'NE1', 'winner': 'Trump'},
#     'NE2': {'state': 'NE2', 'winner': 'Biden'},
#     'NE3': {'state': 'NE3', 'winner': 'Trump'},
#     'NH': {'state': 'NH', 'winner': 'Biden'},
#     'NJ': {'state': 'NJ', 'winner': 'Biden'},
#     'NM': {'state': 'NM', 'winner': 'Biden'},
#     'NV': {'state': 'NV', 'winner': 'Biden'},
#     'NY': {'state': 'NY', 'winner': 'Biden'},
#     'OH': {'state': 'OH', 'winner': 'Biden'},
#     'OK': {'state': 'OK', 'winner': 'Trump'},
#     'OR': {'state': 'OR', 'winner': 'Biden'},
#     'PA': {'state': 'PA', 'winner': 'Biden'},
#     'RI': {'state': 'RI', 'winner': 'Biden'},
#     'SC': {'state': 'SC', 'winner': 'Trump'},
#     'SD': {'state': 'SD', 'winner': 'Trump'},
#     'TN': {'state': 'TN', 'winner': 'Trump'},
#     'TX': {'state': 'TX', 'winner': 'Trump'},
#     'UT': {'state': 'UT', 'winner': 'Trump'},
#     'VA': {'state': 'VA', 'winner': 'Biden'},
#     'VT': {'state': 'VT', 'winner': 'Biden'},
#     'WA': {'state': 'WA', 'winner': 'Biden'},
#     'WI': {'state': 'WI', 'winner': 'Biden'},
#     'WV': {'state': 'WV', 'winner': 'Trump'},
#     'WY': {'state': 'WY', 'winner': 'Trump'}}},
#   {'winner': 'Biden',
#    'evs': {'Biden': 343, 'Trump': 195},
#    'states': {'AK': {'state': 'AK', 'winner': 'Trump'},
#     'AL': {'state': 'AL', 'winner': 'Trump'},
#     'AR': {'state': 'AR', 'winner': 'Trump'},
#     'AZ': {'state': 'AZ', 'winner': 'Biden'},
#     'CA': {'state': 'CA', 'winner': 'Biden'},
#     'CO': {'state': 'CO', 'winner': 'Biden'},
#     'CT': {'state': 'CT', 'winner': 'Biden'},
#     'DC': {'state': 'DC', 'winner': 'Biden'},
#     'DE': {'state': 'DE', 'winner': 'Biden'},
#     'FL': {'state': 'FL', 'winner': 'Biden'},
#     'GA': {'state': 'GA', 'winner': 'Trump'},
#     'HI': {'state': 'HI', 'winner': 'Biden'},
#     'IA': {'state': 'IA', 'winner': 'Biden'},
#     'ID': {'state': 'ID', 'winner': 'Trump'},
#     'IL': {'state': 'IL', 'winner': 'Biden'},
#     'IN': {'state': 'IN', 'winner': 'Trump'},
#     'KS': {'state': 'KS', 'winner': 'Trump'},
#     'KY': {'state': 'KY', 'winner': 'Trump'},
#     'LA': {'state': 'LA', 'winner': 'Trump'},
#     'MA': {'state': 'MA', 'winner': 'Biden'},
#     'MD': {'state': 'MD', 'winner': 'Biden'},
#     'ME': {'state': 'ME', 'winner': 'Biden'},
#     'ME1': {'state': 'ME1', 'winner': 'Biden'},
#     'ME2': {'state': 'ME2', 'winner': 'Trump'},
#     'MI': {'state': 'MI', 'winner': 'Biden'},
#     'MN': {'state': 'MN', 'winner': 'Biden'},
#     'MO': {'state': 'MO', 'winner': 'Trump'},
#     'MS': {'state': 'MS', 'winner': 'Trump'},
#     'MT': {'state': 'MT', 'winner': 'Trump'},
#     'NC': {'state': 'NC', 'winner': 'Trump'},
#     'ND': {'state': 'ND', 'winner': 'Trump'},
#     'NE': {'state': 'NE', 'winner': 'Trump'},
#     'NE1': {'state': 'NE1', 'winner': 'Trump'},
#     'NE2': {'state': 'NE2', 'winner': 'Biden'},
#     'NE3': {'state': 'NE3', 'winner': 'Trump'},
#     'NH': {'state': 'NH', 'winner': 'Biden'},
#     'NJ': {'state': 'NJ', 'winner': 'Biden'},
#     'NM': {'state': 'NM', 'winner': 'Biden'},
#     'NV': {'state': 'NV', 'winner': 'Biden'},
#     'NY': {'state': 'NY', 'winner': 'Biden'},
#     'OH': {'state': 'OH', 'winner': 'Biden'},
#     'OK': {'state': 'OK', 'winner': 'Trump'},
#     'OR': {'state': 'OR', 'winner': 'Biden'},
#     'PA': {'state': 'PA', 'winner': 'Biden'},
#     'RI': {'state': 'RI', 'winner': 'Biden'},
#     'SC': {'state': 'SC', 'winner': 'Trump'},
#     'SD': {'state': 'SD', 'winner': 'Trump'},
#     'TN': {'state': 'TN', 'winner': 'Trump'},
#     'TX': {'state': 'TX', 'winner': 'Trump'},
#     'UT': {'state': 'UT', 'winner': 'Trump'},
#     'VA': {'state': 'VA', 'winner': 'Biden'},
#     'VT': {'state': 'VT', 'winner': 'Biden'},
#     'WA': {'state': 'WA', 'winner': 'Biden'},
#     'WI': {'state': 'WI', 'winner': 'Biden'},
#     'WV': {'state': 'WV', 'winner': 'Trump'},
#     'WY': {'state': 'WY', 'winner': 'Trump'}}},
#   {'winner': 'Biden',
#    'evs': {'Biden': 293, 'Trump': 245},
#    'states': {'AK': {'state': 'AK', 'winner': 'Trump'},
#     'AL': {'state': 'AL', 'winner': 'Trump'},
#     'AR': {'state': 'AR', 'winner': 'Trump'},
#     'AZ': {'state': 'AZ', 'winner': 'Trump'},
#     'CA': {'state': 'CA', 'winner': 'Biden'},
#     'CO': {'state': 'CO', 'winner': 'Biden'},
#     'CT': {'state': 'CT', 'winner': 'Biden'},
#     'DC': {'state': 'DC', 'winner': 'Biden'},
#     'DE': {'state': 'DE', 'winner': 'Biden'},
#     'FL': {'state': 'FL', 'winner': 'Trump'},
#     'GA': {'state': 'GA', 'winner': 'Trump'},
#     'HI': {'state': 'HI', 'winner': 'Biden'},
#     'IA': {'state': 'IA', 'winner': 'Trump'},
#     'ID': {'state': 'ID', 'winner': 'Trump'},
#     'IL': {'state': 'IL', 'winner': 'Biden'},
#     'IN': {'state': 'IN', 'winner': 'Trump'},
#     'KS': {'state': 'KS', 'winner': 'Trump'},
#     'KY': {'state': 'KY', 'winner': 'Trump'},
#     'LA': {'state': 'LA', 'winner': 'Trump'},
#     'MA': {'state': 'MA', 'winner': 'Biden'},
#     'MD': {'state': 'MD', 'winner': 'Biden'},
#     'ME': {'state': 'ME', 'winner': 'Biden'},
#     'ME1': {'state': 'ME1', 'winner': 'Biden'},
#     'ME2': {'state': 'ME2', 'winner': 'Biden'},
#     'MI': {'state': 'MI', 'winner': 'Biden'},
#     'MN': {'state': 'MN', 'winner': 'Biden'},
#     'MO': {'state': 'MO', 'winner': 'Trump'},
#     'MS': {'state': 'MS', 'winner': 'Trump'},
#     'MT': {'state': 'MT', 'winner': 'Trump'},
#     'NC': {'state': 'NC', 'winner': 'Trump'},
#     'ND': {'state': 'ND', 'winner': 'Trump'},
#     'NE': {'state': 'NE', 'winner': 'Trump'},
#     'NE1': {'state': 'NE1', 'winner': 'Trump'},
#     'NE2': {'state': 'NE2', 'winner': 'Biden'},
#     'NE3': {'state': 'NE3', 'winner': 'Trump'},
#     'NH': {'state': 'NH', 'winner': 'Biden'},
#     'NJ': {'state': 'NJ', 'winner': 'Biden'},
#     'NM': {'state': 'NM', 'winner': 'Trump'},
#     'NV': {'state': 'NV', 'winner': 'Biden'},
#     'NY': {'state': 'NY', 'winner': 'Biden'},
#     'OH': {'state': 'OH', 'winner': 'Biden'},
#     'OK': {'state': 'OK', 'winner': 'Trump'},
#     'OR': {'state': 'OR', 'winner': 'Biden'},
#     'PA': {'state': 'PA', 'winner': 'Biden'},
#     'RI': {'state': 'RI', 'winner': 'Biden'},
#     'SC': {'state': 'SC', 'winner': 'Trump'},
#     'SD': {'state': 'SD', 'winner': 'Trump'},
#     'TN': {'state': 'TN', 'winner': 'Trump'},
#     'TX': {'state': 'TX', 'winner': 'Trump'},
#     'UT': {'state': 'UT', 'winner': 'Trump'},
#     'VA': {'state': 'VA', 'winner': 'Biden'},
#     'VT': {'state': 'VT', 'winner': 'Biden'},
#     'WA': {'state': 'WA', 'winner': 'Biden'},
#     'WI': {'state': 'WI', 'winner': 'Biden'},
#     'WV': {'state': 'WV', 'winner': 'Trump'},
#     'WY': {'state': 'WY', 'winner': 'Trump'}}},
#   {'winner': 'Biden',
#    'evs': {'Biden': 316, 'Trump': 222},
#    'states': {'AK': {'state': 'AK', 'winner': 'Trump'},
#     'AL': {'state': 'AL', 'winner': 'Trump'},
#     'AR': {'state': 'AR', 'winner': 'Trump'},
#     'AZ': {'state': 'AZ', 'winner': 'Trump'},
#     'CA': {'state': 'CA', 'winner': 'Biden'},
#     'CO': {'state': 'CO', 'winner': 'Biden'},
#     'CT': {'state': 'CT', 'winner': 'Biden'},
#     'DC': {'state': 'DC', 'winner': 'Biden'},
#     'DE': {'state': 'DE', 'winner': 'Biden'},
#     'FL': {'state': 'FL', 'winner': 'Trump'},
#     'GA': {'state': 'GA', 'winner': 'Trump'},
#     'HI': {'state': 'HI', 'winner': 'Biden'},
#     'IA': {'state': 'IA', 'winner': 'Trump'},
#     'ID': {'state': 'ID', 'winner': 'Trump'},
#     'IL': {'state': 'IL', 'winner': 'Biden'},
#     'IN': {'state': 'IN', 'winner': 'Trump'},
#     'KS': {'state': 'KS', 'winner': 'Trump'},
#     'KY': {'state': 'KY', 'winner': 'Trump'},
#     'LA': {'state': 'LA', 'winner': 'Trump'},
#     'MA': {'state': 'MA', 'winner': 'Biden'},
#     'MD': {'state': 'MD', 'winner': 'Biden'},
#     'ME': {'state': 'ME', 'winner': 'Biden'},
#     'ME1': {'state': 'ME1', 'winner': 'Biden'},
#     'ME2': {'state': 'ME2', 'winner': 'Biden'},
#     'MI': {'state': 'MI', 'winner': 'Trump'},
#     'MN': {'state': 'MN', 'winner': 'Biden'},
#     'MO': {'state': 'MO', 'winner': 'Trump'},
#     'MS': {'state': 'MS', 'winner': 'Trump'},
#     'MT': {'state': 'MT', 'winner': 'Trump'},
#     'NC': {'state': 'NC', 'winner': 'Biden'},
#     'ND': {'state': 'ND', 'winner': 'Trump'},
#     'NE': {'state': 'NE', 'winner': 'Trump'},
#     'NE1': {'state': 'NE1', 'winner': 'Trump'},
#     'NE2': {'state': 'NE2', 'winner': 'Trump'},
#     'NE3': {'state': 'NE3', 'winner': 'Trump'},
#     'NH': {'state': 'NH', 'winner': 'Biden'},
#     'NJ': {'state': 'NJ', 'winner': 'Biden'},
#     'NM': {'state': 'NM', 'winner': 'Biden'},
#     'NV': {'state': 'NV', 'winner': 'Biden'},
#     'NY': {'state': 'NY', 'winner': 'Biden'},
#     'OH': {'state': 'OH', 'winner': 'Trump'},
#     'OK': {'state': 'OK', 'winner': 'Trump'},
#     'OR': {'state': 'OR', 'winner': 'Biden'},
#     'PA': {'state': 'PA', 'winner': 'Biden'},
#     'RI': {'state': 'RI', 'winner': 'Biden'},
#     'SC': {'state': 'SC', 'winner': 'Trump'},
#     'SD': {'state': 'SD', 'winner': 'Trump'},
#     'TN': {'state': 'TN', 'winner': 'Trump'},
#     'TX': {'state': 'TX', 'winner': 'Biden'},
#     'UT': {'state': 'UT', 'winner': 'Trump'},
#     'VA': {'state': 'VA', 'winner': 'Biden'},
#     'VT': {'state': 'VT', 'winner': 'Biden'},
#     'WA': {'state': 'WA', 'winner': 'Biden'},
#     'WI': {'state': 'WI', 'winner': 'Biden'},
#     'WV': {'state': 'WV', 'winner': 'Trump'},
#     'WY': {'state': 'WY', 'winner': 'Trump'}}},
#   {'winner': 'Trump',
#    'evs': {'Biden': 258, 'Trump': 280},
#    'states': {'AK': {'state': 'AK', 'winner': 'Trump'},
#     'AL': {'state': 'AL', 'winner': 'Trump'},
#     'AR': {'state': 'AR', 'winner': 'Trump'},
#     'AZ': {'state': 'AZ', 'winner': 'Trump'},
#     'CA': {'state': 'CA', 'winner': 'Biden'},
#     'CO': {'state': 'CO', 'winner': 'Biden'},
#     'CT': {'state': 'CT', 'winner': 'Biden'},
#     'DC': {'state': 'DC', 'winner': 'Biden'},
#     'DE': {'state': 'DE', 'winner': 'Biden'},
#     'FL': {'state': 'FL', 'winner': 'Trump'},
#     'GA': {'state': 'GA', 'winner': 'Trump'},
#     'HI': {'state': 'HI', 'winner': 'Biden'},
#     'IA': {'state': 'IA', 'winner': 'Trump'},
#     'ID': {'state': 'ID', 'winner': 'Trump'},
#     'IL': {'state': 'IL', 'winner': 'Biden'},
#     'IN': {'state': 'IN', 'winner': 'Trump'},
#     'KS': {'state': 'KS', 'winner': 'Trump'},
#     'KY': {'state': 'KY', 'winner': 'Trump'},
#     'LA': {'state': 'LA', 'winner': 'Trump'},
#     'MA': {'state': 'MA', 'winner': 'Biden'},
#     'MD': {'state': 'MD', 'winner': 'Biden'},
#     'ME': {'state': 'ME', 'winner': 'Biden'},
#     'ME1': {'state': 'ME1', 'winner': 'Biden'},
#     'ME2': {'state': 'ME2', 'winner': 'Trump'},
#     'MI': {'state': 'MI', 'winner': 'Biden'},
#     'MN': {'state': 'MN', 'winner': 'Biden'},
#     'MO': {'state': 'MO', 'winner': 'Trump'},
#     'MS': {'state': 'MS', 'winner': 'Trump'},
#     'MT': {'state': 'MT', 'winner': 'Trump'},
#     'NC': {'state': 'NC', 'winner': 'Trump'},
#     'ND': {'state': 'ND', 'winner': 'Trump'},
#     'NE': {'state': 'NE', 'winner': 'Trump'},
#     'NE1': {'state': 'NE1', 'winner': 'Trump'},
#     'NE2': {'state': 'NE2', 'winner': 'Trump'},
#     'NE3': {'state': 'NE3', 'winner': 'Trump'},
#     'NH': {'state': 'NH', 'winner': 'Biden'},
#     'NJ': {'state': 'NJ', 'winner': 'Biden'},
#     'NM': {'state': 'NM', 'winner': 'Biden'},
#     'NV': {'state': 'NV', 'winner': 'Biden'},
#     'NY': {'state': 'NY', 'winner': 'Biden'},
#     'OH': {'state': 'OH', 'winner': 'Trump'},
#     'OK': {'state': 'OK', 'winner': 'Trump'},
#     'OR': {'state': 'OR', 'winner': 'Biden'},
#     'PA': {'state': 'PA', 'winner': 'Trump'},
#     'RI': {'state': 'RI', 'winner': 'Biden'},
#     'SC': {'state': 'SC', 'winner': 'Trump'},
#     'SD': {'state': 'SD', 'winner': 'Trump'},
#     'TN': {'state': 'TN', 'winner': 'Trump'},
#     'TX': {'state': 'TX', 'winner': 'Trump'},
#     'UT': {'state': 'UT', 'winner': 'Trump'},
#     'VA': {'state': 'VA', 'winner': 'Biden'},
#     'VT': {'state': 'VT', 'winner': 'Biden'},
#     'WA': {'state': 'WA', 'winner': 'Biden'},
#     'WI': {'state': 'WI', 'winner': 'Biden'},
#     'WV': {'state': 'WV', 'winner': 'Trump'},
#     'WY': {'state': 'WY', 'winner': 'Trump'}}},
#   {'winner': 'Biden',
#    'evs': {'Biden': 323, 'Trump': 215},
#    'states': {'AK': {'state': 'AK', 'winner': 'Trump'},
#     'AL': {'state': 'AL', 'winner': 'Trump'},
#     'AR': {'state': 'AR', 'winner': 'Trump'},
#     'AZ': {'state': 'AZ', 'winner': 'Trump'},
#     'CA': {'state': 'CA', 'winner': 'Biden'},
#     'CO': {'state': 'CO', 'winner': 'Biden'},
#     'CT': {'state': 'CT', 'winner': 'Biden'},
#     'DC': {'state': 'DC', 'winner': 'Biden'},
#     'DE': {'state': 'DE', 'winner': 'Biden'},
#     'FL': {'state': 'FL', 'winner': 'Biden'},
#     'GA': {'state': 'GA', 'winner': 'Trump'},
#     'HI': {'state': 'HI', 'winner': 'Biden'},
#     'IA': {'state': 'IA', 'winner': 'Trump'},
#     'ID': {'state': 'ID', 'winner': 'Trump'},
#     'IL': {'state': 'IL', 'winner': 'Biden'},
#     'IN': {'state': 'IN', 'winner': 'Trump'},
#     'KS': {'state': 'KS', 'winner': 'Trump'},
#     'KY': {'state': 'KY', 'winner': 'Trump'},
#     'LA': {'state': 'LA', 'winner': 'Trump'},
#     'MA': {'state': 'MA', 'winner': 'Biden'},
#     'MD': {'state': 'MD', 'winner': 'Biden'},
#     'ME': {'state': 'ME', 'winner': 'Biden'},
#     'ME1': {'state': 'ME1', 'winner': 'Biden'},
#     'ME2': {'state': 'ME2', 'winner': 'Trump'},
#     'MI': {'state': 'MI', 'winner': 'Biden'},
#     'MN': {'state': 'MN', 'winner': 'Biden'},
#     'MO': {'state': 'MO', 'winner': 'Trump'},
#     'MS': {'state': 'MS', 'winner': 'Trump'},
#     'MT': {'state': 'MT', 'winner': 'Trump'},
#     'NC': {'state': 'NC', 'winner': 'Biden'},
#     'ND': {'state': 'ND', 'winner': 'Trump'},
#     'NE': {'state': 'NE', 'winner': 'Trump'},
#     'NE1': {'state': 'NE1', 'winner': 'Trump'},
#     'NE2': {'state': 'NE2', 'winner': 'Biden'},
#     'NE3': {'state': 'NE3', 'winner': 'Trump'},
#     'NH': {'state': 'NH', 'winner': 'Biden'},
#     'NJ': {'state': 'NJ', 'winner': 'Biden'},
#     'NM': {'state': 'NM', 'winner': 'Biden'},
#     'NV': {'state': 'NV', 'winner': 'Biden'},
#     'NY': {'state': 'NY', 'winner': 'Biden'},
#     'OH': {'state': 'OH', 'winner': 'Trump'},
#     'OK': {'state': 'OK', 'winner': 'Trump'},
#     'OR': {'state': 'OR', 'winner': 'Biden'},
#     'PA': {'state': 'PA', 'winner': 'Biden'},
#     'RI': {'state': 'RI', 'winner': 'Biden'},
#     'SC': {'state': 'SC', 'winner': 'Trump'},
#     'SD': {'state': 'SD', 'winner': 'Trump'},
#     'TN': {'state': 'TN', 'winner': 'Trump'},
#     'TX': {'state': 'TX', 'winner': 'Trump'},
#     'UT': {'state': 'UT', 'winner': 'Trump'},
#     'VA': {'state': 'VA', 'winner': 'Biden'},
#     'VT': {'state': 'VT', 'winner': 'Biden'},
#     'WA': {'state': 'WA', 'winner': 'Biden'},
#     'WI': {'state': 'WI', 'winner': 'Biden'},
#     'WV': {'state': 'WV', 'winner': 'Trump'},
#     'WY': {'state': 'WY', 'winner': 'Trump'}}},
#   {'winner': 'Biden',
#    'evs': {'Biden': 278, 'Trump': 260},
#    'states': {'AK': {'state': 'AK', 'winner': 'Trump'},
#     'AL': {'state': 'AL', 'winner': 'Trump'},
#     'AR': {'state': 'AR', 'winner': 'Trump'},
#     'AZ': {'state': 'AZ', 'winner': 'Biden'},
#     'CA': {'state': 'CA', 'winner': 'Biden'},
#     'CO': {'state': 'CO', 'winner': 'Biden'},
#     'CT': {'state': 'CT', 'winner': 'Biden'},
#     'DC': {'state': 'DC', 'winner': 'Biden'},
#     'DE': {'state': 'DE', 'winner': 'Biden'},
#     'FL': {'state': 'FL', 'winner': 'Trump'},
#     'GA': {'state': 'GA', 'winner': 'Trump'},
#     'HI': {'state': 'HI', 'winner': 'Biden'},
#     'IA': {'state': 'IA', 'winner': 'Trump'},
#     'ID': {'state': 'ID', 'winner': 'Trump'},
#     'IL': {'state': 'IL', 'winner': 'Biden'},
#     'IN': {'state': 'IN', 'winner': 'Trump'},
#     'KS': {'state': 'KS', 'winner': 'Trump'},
#     'KY': {'state': 'KY', 'winner': 'Trump'},
#     'LA': {'state': 'LA', 'winner': 'Trump'},
#     'MA': {'state': 'MA', 'winner': 'Biden'},
#     'MD': {'state': 'MD', 'winner': 'Biden'},
#     'ME': {'state': 'ME', 'winner': 'Trump'},
#     'ME1': {'state': 'ME1', 'winner': 'Biden'},
#     'ME2': {'state': 'ME2', 'winner': 'Trump'},
#     'MI': {'state': 'MI', 'winner': 'Biden'},
#     'MN': {'state': 'MN', 'winner': 'Biden'},
#     'MO': {'state': 'MO', 'winner': 'Trump'},
#     'MS': {'state': 'MS', 'winner': 'Trump'},
#     'MT': {'state': 'MT', 'winner': 'Trump'},
#     'NC': {'state': 'NC', 'winner': 'Biden'},
#     'ND': {'state': 'ND', 'winner': 'Trump'},
#     'NE': {'state': 'NE', 'winner': 'Trump'},
#     'NE1': {'state': 'NE1', 'winner': 'Trump'},
#     'NE2': {'state': 'NE2', 'winner': 'Trump'},
#     'NE3': {'state': 'NE3', 'winner': 'Trump'},
#     'NH': {'state': 'NH', 'winner': 'Trump'},
#     'NJ': {'state': 'NJ', 'winner': 'Biden'},
#     'NM': {'state': 'NM', 'winner': 'Biden'},
#     'NV': {'state': 'NV', 'winner': 'Biden'},
#     'NY': {'state': 'NY', 'winner': 'Biden'},
#     'OH': {'state': 'OH', 'winner': 'Trump'},
#     'OK': {'state': 'OK', 'winner': 'Trump'},
#     'OR': {'state': 'OR', 'winner': 'Biden'},
#     'PA': {'state': 'PA', 'winner': 'Trump'},
#     'RI': {'state': 'RI', 'winner': 'Biden'},
#     'SC': {'state': 'SC', 'winner': 'Trump'},
#     'SD': {'state': 'SD', 'winner': 'Trump'},
#     'TN': {'state': 'TN', 'winner': 'Trump'},
#     'TX': {'state': 'TX', 'winner': 'Trump'},
#     'UT': {'state': 'UT', 'winner': 'Trump'},
#     'VA': {'state': 'VA', 'winner': 'Biden'},
#     'VT': {'state': 'VT', 'winner': 'Biden'},
#     'WA': {'state': 'WA', 'winner': 'Biden'},
#     'WI': {'state': 'WI', 'winner': 'Biden'},
#     'WV': {'state': 'WV', 'winner': 'Trump'},
#     'WY': {'state': 'WY', 'winner': 'Trump'}}},
#   {'winner': 'Biden',
#    'evs': {'Biden': 400, 'Trump': 138},
#    'states': {'AK': {'state': 'AK', 'winner': 'Trump'},
#     'AL': {'state': 'AL', 'winner': 'Trump'},
#     'AR': {'state': 'AR', 'winner': 'Trump'},
#     'AZ': {'state': 'AZ', 'winner': 'Biden'},
#     'CA': {'state': 'CA', 'winner': 'Biden'},
#     'CO': {'state': 'CO', 'winner': 'Biden'},
#     'CT': {'state': 'CT', 'winner': 'Biden'},
#     'DC': {'state': 'DC', 'winner': 'Biden'},
#     'DE': {'state': 'DE', 'winner': 'Biden'},
#     'FL': {'state': 'FL', 'winner': 'Biden'},
#     'GA': {'state': 'GA', 'winner': 'Biden'},
#     'HI': {'state': 'HI', 'winner': 'Biden'},
#     'IA': {'state': 'IA', 'winner': 'Biden'},
#     'ID': {'state': 'ID', 'winner': 'Trump'},
#     'IL': {'state': 'IL', 'winner': 'Biden'},
#     'IN': {'state': 'IN', 'winner': 'Trump'},
#     'KS': {'state': 'KS', 'winner': 'Trump'},
#     'KY': {'state': 'KY', 'winner': 'Trump'},
#     'LA': {'state': 'LA', 'winner': 'Trump'},
#     'MA': {'state': 'MA', 'winner': 'Biden'},
#     'MD': {'state': 'MD', 'winner': 'Biden'},
#     'ME': {'state': 'ME', 'winner': 'Biden'},
#     'ME1': {'state': 'ME1', 'winner': 'Biden'},
#     'ME2': {'state': 'ME2', 'winner': 'Trump'},
#     'MI': {'state': 'MI', 'winner': 'Biden'},
#     'MN': {'state': 'MN', 'winner': 'Biden'},
#     'MO': {'state': 'MO', 'winner': 'Trump'},
#     'MS': {'state': 'MS', 'winner': 'Biden'},
#     'MT': {'state': 'MT', 'winner': 'Trump'},
#     'NC': {'state': 'NC', 'winner': 'Biden'},
#     'ND': {'state': 'ND', 'winner': 'Trump'},
#     'NE': {'state': 'NE', 'winner': 'Trump'},
#     'NE1': {'state': 'NE1', 'winner': 'Trump'},
#     'NE2': {'state': 'NE2', 'winner': 'Biden'},
#     'NE3': {'state': 'NE3', 'winner': 'Trump'},
#     'NH': {'state': 'NH', 'winner': 'Biden'},
#     'NJ': {'state': 'NJ', 'winner': 'Biden'},
#     'NM': {'state': 'NM', 'winner': 'Biden'},
#     'NV': {'state': 'NV', 'winner': 'Biden'},
#     'NY': {'state': 'NY', 'winner': 'Biden'},
#     'OH': {'state': 'OH', 'winner': 'Trump'},
#     'OK': {'state': 'OK', 'winner': 'Trump'},
#     'OR': {'state': 'OR', 'winner': 'Biden'},
#     'PA': {'state': 'PA', 'winner': 'Biden'},
#     'RI': {'state': 'RI', 'winner': 'Biden'},
#     'SC': {'state': 'SC', 'winner': 'Trump'},
#     'SD': {'state': 'SD', 'winner': 'Trump'},
#     'TN': {'state': 'TN', 'winner': 'Trump'},
#     'TX': {'state': 'TX', 'winner': 'Biden'},
#     'UT': {'state': 'UT', 'winner': 'Trump'},
#     'VA': {'state': 'VA', 'winner': 'Biden'},
#     'VT': {'state': 'VT', 'winner': 'Biden'},
#     'WA': {'state': 'WA', 'winner': 'Biden'},
#     'WI': {'state': 'WI', 'winner': 'Biden'},
#     'WV': {'state': 'WV', 'winner': 'Trump'},
#     'WY': {'state': 'WY', 'winner': 'Trump'}}},
#   {'winner': 'Biden',
#    'evs': {'Biden': 341, 'Trump': 197},
#    'states': {'AK': {'state': 'AK', 'winner': 'Trump'},
#     'AL': {'state': 'AL', 'winner': 'Trump'},
#     'AR': {'state': 'AR', 'winner': 'Trump'},
#     'AZ': {'state': 'AZ', 'winner': 'Trump'},
#     'CA': {'state': 'CA', 'winner': 'Biden'},
#     'CO': {'state': 'CO', 'winner': 'Biden'},
#     'CT': {'state': 'CT', 'winner': 'Biden'},
#     'DC': {'state': 'DC', 'winner': 'Biden'},
#     'DE': {'state': 'DE', 'winner': 'Biden'},
#     'FL': {'state': 'FL', 'winner': 'Biden'},
#     'GA': {'state': 'GA', 'winner': 'Trump'},
#     'HI': {'state': 'HI', 'winner': 'Biden'},
#     'IA': {'state': 'IA', 'winner': 'Trump'},
#     'ID': {'state': 'ID', 'winner': 'Trump'},
#     'IL': {'state': 'IL', 'winner': 'Biden'},
#     'IN': {'state': 'IN', 'winner': 'Trump'},
#     'KS': {'state': 'KS', 'winner': 'Trump'},
#     'KY': {'state': 'KY', 'winner': 'Trump'},
#     'LA': {'state': 'LA', 'winner': 'Trump'},
#     'MA': {'state': 'MA', 'winner': 'Biden'},
#     'MD': {'state': 'MD', 'winner': 'Biden'},
#     'ME': {'state': 'ME', 'winner': 'Biden'},
#     'ME1': {'state': 'ME1', 'winner': 'Biden'},
#     'ME2': {'state': 'ME2', 'winner': 'Trump'},
#     'MI': {'state': 'MI', 'winner': 'Biden'},
#     'MN': {'state': 'MN', 'winner': 'Biden'},
#     'MO': {'state': 'MO', 'winner': 'Trump'},
#     'MS': {'state': 'MS', 'winner': 'Trump'},
#     'MT': {'state': 'MT', 'winner': 'Trump'},
#     'NC': {'state': 'NC', 'winner': 'Biden'},
#     'ND': {'state': 'ND', 'winner': 'Trump'},
#     'NE': {'state': 'NE', 'winner': 'Trump'},
#     'NE1': {'state': 'NE1', 'winner': 'Trump'},
#     'NE2': {'state': 'NE2', 'winner': 'Biden'},
#     'NE3': {'state': 'NE3', 'winner': 'Trump'},
#     'NH': {'state': 'NH', 'winner': 'Biden'},
#     'NJ': {'state': 'NJ', 'winner': 'Biden'},
#     'NM': {'state': 'NM', 'winner': 'Biden'},
#     'NV': {'state': 'NV', 'winner': 'Biden'},
#     'NY': {'state': 'NY', 'winner': 'Biden'},
#     'OH': {'state': 'OH', 'winner': 'Biden'},
#     'OK': {'state': 'OK', 'winner': 'Trump'},
#     'OR': {'state': 'OR', 'winner': 'Biden'},
#     'PA': {'state': 'PA', 'winner': 'Biden'},
#     'RI': {'state': 'RI', 'winner': 'Biden'},
#     'SC': {'state': 'SC', 'winner': 'Trump'},
#     'SD': {'state': 'SD', 'winner': 'Trump'},
#     'TN': {'state': 'TN', 'winner': 'Trump'},
#     'TX': {'state': 'TX', 'winner': 'Trump'},
#     'UT': {'state': 'UT', 'winner': 'Trump'},
#     'VA': {'state': 'VA', 'winner': 'Biden'},
#     'VT': {'state': 'VT', 'winner': 'Biden'},
#     'WA': {'state': 'WA', 'winner': 'Biden'},
#     'WI': {'state': 'WI', 'winner': 'Biden'},
#     'WV': {'state': 'WV', 'winner': 'Trump'},
#     'WY': {'state': 'WY', 'winner': 'Trump'}}},
#   {'winner': 'Biden',
#    'evs': {'Biden': 418, 'Trump': 120},
#    'states': {'AK': {'state': 'AK', 'winner': 'Trump'},
#     'AL': {'state': 'AL', 'winner': 'Trump'},
#     'AR': {'state': 'AR', 'winner': 'Trump'},
#     'AZ': {'state': 'AZ', 'winner': 'Biden'},
#     'CA': {'state': 'CA', 'winner': 'Biden'},
#     'CO': {'state': 'CO', 'winner': 'Biden'},
#     'CT': {'state': 'CT', 'winner': 'Biden'},
#     'DC': {'state': 'DC', 'winner': 'Biden'},
#     'DE': {'state': 'DE', 'winner': 'Biden'},
#     'FL': {'state': 'FL', 'winner': 'Biden'},
#     'GA': {'state': 'GA', 'winner': 'Biden'},
#     'HI': {'state': 'HI', 'winner': 'Biden'},
#     'IA': {'state': 'IA', 'winner': 'Biden'},
#     'ID': {'state': 'ID', 'winner': 'Trump'},
#     'IL': {'state': 'IL', 'winner': 'Biden'},
#     'IN': {'state': 'IN', 'winner': 'Trump'},
#     'KS': {'state': 'KS', 'winner': 'Trump'},
#     'KY': {'state': 'KY', 'winner': 'Trump'},
#     'LA': {'state': 'LA', 'winner': 'Trump'},
#     'MA': {'state': 'MA', 'winner': 'Biden'},
#     'MD': {'state': 'MD', 'winner': 'Biden'},
#     'ME': {'state': 'ME', 'winner': 'Biden'},
#     'ME1': {'state': 'ME1', 'winner': 'Biden'},
#     'ME2': {'state': 'ME2', 'winner': 'Trump'},
#     'MI': {'state': 'MI', 'winner': 'Biden'},
#     'MN': {'state': 'MN', 'winner': 'Biden'},
#     'MO': {'state': 'MO', 'winner': 'Trump'},
#     'MS': {'state': 'MS', 'winner': 'Biden'},
#     'MT': {'state': 'MT', 'winner': 'Trump'},
#     'NC': {'state': 'NC', 'winner': 'Biden'},
#     'ND': {'state': 'ND', 'winner': 'Trump'},
#     'NE': {'state': 'NE', 'winner': 'Trump'},
#     'NE1': {'state': 'NE1', 'winner': 'Trump'},
#     'NE2': {'state': 'NE2', 'winner': 'Biden'},
#     'NE3': {'state': 'NE3', 'winner': 'Trump'},
#     'NH': {'state': 'NH', 'winner': 'Biden'},
#     'NJ': {'state': 'NJ', 'winner': 'Biden'},
#     'NM': {'state': 'NM', 'winner': 'Biden'},
#     'NV': {'state': 'NV', 'winner': 'Biden'},
#     'NY': {'state': 'NY', 'winner': 'Biden'},
#     'OH': {'state': 'OH', 'winner': 'Biden'},
#     'OK': {'state': 'OK', 'winner': 'Trump'},
#     'OR': {'state': 'OR', 'winner': 'Biden'},
#     'PA': {'state': 'PA', 'winner': 'Biden'},
#     'RI': {'state': 'RI', 'winner': 'Biden'},
#     'SC': {'state': 'SC', 'winner': 'Trump'},
#     'SD': {'state': 'SD', 'winner': 'Trump'},
#     'TN': {'state': 'TN', 'winner': 'Trump'},
#     'TX': {'state': 'TX', 'winner': 'Biden'},
#     'UT': {'state': 'UT', 'winner': 'Trump'},
#     'VA': {'state': 'VA', 'winner': 'Biden'},
#     'VT': {'state': 'VT', 'winner': 'Biden'},
#     'WA': {'state': 'WA', 'winner': 'Biden'},
#     'WI': {'state': 'WI', 'winner': 'Biden'},
#     'WV': {'state': 'WV', 'winner': 'Trump'},
#     'WY': {'state': 'WY', 'winner': 'Trump'}}},
#   {'winner': 'Biden',
#    'evs': {'Biden': 358, 'Trump': 180},
#    'states': {'AK': {'state': 'AK', 'winner': 'Biden'},
#     'AL': {'state': 'AL', 'winner': 'Trump'},
#     'AR': {'state': 'AR', 'winner': 'Trump'},
#     'AZ': {'state': 'AZ', 'winner': 'Biden'},
#     'CA': {'state': 'CA', 'winner': 'Biden'},
#     'CO': {'state': 'CO', 'winner': 'Biden'},
#     'CT': {'state': 'CT', 'winner': 'Biden'},
#     'DC': {'state': 'DC', 'winner': 'Biden'},
#     'DE': {'state': 'DE', 'winner': 'Biden'},
#     'FL': {'state': 'FL', 'winner': 'Biden'},
#     'GA': {'state': 'GA', 'winner': 'Biden'},
#     'HI': {'state': 'HI', 'winner': 'Biden'},
#     'IA': {'state': 'IA', 'winner': 'Biden'},
#     'ID': {'state': 'ID', 'winner': 'Trump'},
#     'IL': {'state': 'IL', 'winner': 'Biden'},
#     'IN': {'state': 'IN', 'winner': 'Trump'},
#     'KS': {'state': 'KS', 'winner': 'Trump'},
#     'KY': {'state': 'KY', 'winner': 'Trump'},
#     'LA': {'state': 'LA', 'winner': 'Trump'},
#     'MA': {'state': 'MA', 'winner': 'Biden'},
#     'MD': {'state': 'MD', 'winner': 'Biden'},
#     'ME': {'state': 'ME', 'winner': 'Biden'},
#     'ME1': {'state': 'ME1', 'winner': 'Biden'},
#     'ME2': {'state': 'ME2', 'winner': 'Trump'},
#     'MI': {'state': 'MI', 'winner': 'Biden'},
#     'MN': {'state': 'MN', 'winner': 'Biden'},
#     'MO': {'state': 'MO', 'winner': 'Trump'},
#     'MS': {'state': 'MS', 'winner': 'Trump'},
#     'MT': {'state': 'MT', 'winner': 'Trump'},
#     'NC': {'state': 'NC', 'winner': 'Biden'},
#     'ND': {'state': 'ND', 'winner': 'Trump'},
#     'NE': {'state': 'NE', 'winner': 'Trump'},
#     'NE1': {'state': 'NE1', 'winner': 'Trump'},
#     'NE2': {'state': 'NE2', 'winner': 'Trump'},
#     'NE3': {'state': 'NE3', 'winner': 'Trump'},
#     'NH': {'state': 'NH', 'winner': 'Biden'},
#     'NJ': {'state': 'NJ', 'winner': 'Biden'},
#     'NM': {'state': 'NM', 'winner': 'Biden'},
#     'NV': {'state': 'NV', 'winner': 'Biden'},
#     'NY': {'state': 'NY', 'winner': 'Biden'},
#     'OH': {'state': 'OH', 'winner': 'Trump'},
#     'OK': {'state': 'OK', 'winner': 'Trump'},
#     'OR': {'state': 'OR', 'winner': 'Biden'},
#     'PA': {'state': 'PA', 'winner': 'Biden'},
#     'RI': {'state': 'RI', 'winner': 'Biden'},
#     'SC': {'state': 'SC', 'winner': 'Trump'},
#     'SD': {'state': 'SD', 'winner': 'Trump'},
#     'TN': {'state': 'TN', 'winner': 'Trump'},
#     'TX': {'state': 'TX', 'winner': 'Trump'},
#     'UT': {'state': 'UT', 'winner': 'Trump'},
#     'VA': {'state': 'VA', 'winner': 'Biden'},
#     'VT': {'state': 'VT', 'winner': 'Biden'},
#     'WA': {'state': 'WA', 'winner': 'Biden'},
#     'WI': {'state': 'WI', 'winner': 'Biden'},
#     'WV': {'state': 'WV', 'winner': 'Trump'},
#     'WY': {'state': 'WY', 'winner': 'Trump'}}},
#   {'winner': 'Biden',
#    'evs': {'Biden': 305, 'Trump': 233},
#    'states': {'AK': {'state': 'AK', 'winner': 'Trump'},
#     'AL': {'state': 'AL', 'winner': 'Trump'},
#     'AR': {'state': 'AR', 'winner': 'Trump'},
#     'AZ': {'state': 'AZ', 'winner': 'Biden'},
#     'CA': {'state': 'CA', 'winner': 'Biden'},
#     'CO': {'state': 'CO', 'winner': 'Biden'},
#     'CT': {'state': 'CT', 'winner': 'Biden'},
#     'DC': {'state': 'DC', 'winner': 'Biden'},
#     'DE': {'state': 'DE', 'winner': 'Biden'},
#     'FL': {'state': 'FL', 'winner': 'Trump'},
#     'GA': {'state': 'GA', 'winner': 'Trump'},
#     'HI': {'state': 'HI', 'winner': 'Biden'},
#     'IA': {'state': 'IA', 'winner': 'Trump'},
#     'ID': {'state': 'ID', 'winner': 'Trump'},
#     'IL': {'state': 'IL', 'winner': 'Biden'},
#     'IN': {'state': 'IN', 'winner': 'Trump'},
#     'KS': {'state': 'KS', 'winner': 'Trump'},
#     'KY': {'state': 'KY', 'winner': 'Trump'},
#     'LA': {'state': 'LA', 'winner': 'Trump'},
#     'MA': {'state': 'MA', 'winner': 'Biden'},
#     'MD': {'state': 'MD', 'winner': 'Biden'},
#     'ME': {'state': 'ME', 'winner': 'Biden'},
#     'ME1': {'state': 'ME1', 'winner': 'Biden'},
#     'ME2': {'state': 'ME2', 'winner': 'Biden'},
#     'MI': {'state': 'MI', 'winner': 'Biden'},
#     'MN': {'state': 'MN', 'winner': 'Biden'},
#     'MO': {'state': 'MO', 'winner': 'Trump'},
#     'MS': {'state': 'MS', 'winner': 'Trump'},
#     'MT': {'state': 'MT', 'winner': 'Trump'},
#     'NC': {'state': 'NC', 'winner': 'Biden'},
#     'ND': {'state': 'ND', 'winner': 'Trump'},
#     'NE': {'state': 'NE', 'winner': 'Trump'},
#     'NE1': {'state': 'NE1', 'winner': 'Trump'},
#     'NE2': {'state': 'NE2', 'winner': 'Trump'},
#     'NE3': {'state': 'NE3', 'winner': 'Trump'},
#     'NH': {'state': 'NH', 'winner': 'Biden'},
#     'NJ': {'state': 'NJ', 'winner': 'Biden'},
#     'NM': {'state': 'NM', 'winner': 'Biden'},
#     'NV': {'state': 'NV', 'winner': 'Biden'},
#     'NY': {'state': 'NY', 'winner': 'Biden'},
#     'OH': {'state': 'OH', 'winner': 'Trump'},
#     'OK': {'state': 'OK', 'winner': 'Trump'},
#     'OR': {'state': 'OR', 'winner': 'Biden'},
#     'PA': {'state': 'PA', 'winner': 'Biden'},
#     'RI': {'state': 'RI', 'winner': 'Biden'},
#     'SC': {'state': 'SC', 'winner': 'Trump'},
#     'SD': {'state': 'SD', 'winner': 'Trump'},
#     'TN': {'state': 'TN', 'winner': 'Trump'},
#     'TX': {'state': 'TX', 'winner': 'Trump'},
#     'UT': {'state': 'UT', 'winner': 'Trump'},
#     'VA': {'state': 'VA', 'winner': 'Biden'},
#     'VT': {'state': 'VT', 'winner': 'Biden'},
#     'WA': {'state': 'WA', 'winner': 'Biden'},
#     'WI': {'state': 'WI', 'winner': 'Biden'},
#     'WV': {'state': 'WV', 'winner': 'Trump'},
#     'WY': {'state': 'WY', 'winner': 'Trump'}}},
#   {'winner': 'Biden',
#    'evs': {'Biden': 337, 'Trump': 201},
#    'states': {'AK': {'state': 'AK', 'winner': 'Biden'},
#     'AL': {'state': 'AL', 'winner': 'Trump'},
#     'AR': {'state': 'AR', 'winner': 'Trump'},
#     'AZ': {'state': 'AZ', 'winner': 'Biden'},
#     'CA': {'state': 'CA', 'winner': 'Biden'},
#     'CO': {'state': 'CO', 'winner': 'Biden'},
#     'CT': {'state': 'CT', 'winner': 'Biden'},
#     'DC': {'state': 'DC', 'winner': 'Biden'},
#     'DE': {'state': 'DE', 'winner': 'Biden'},
#     'FL': {'state': 'FL', 'winner': 'Biden'},
#     'GA': {'state': 'GA', 'winner': 'Trump'},
#     'HI': {'state': 'HI', 'winner': 'Biden'},
#     'IA': {'state': 'IA', 'winner': 'Biden'},
#     'ID': {'state': 'ID', 'winner': 'Trump'},
#     'IL': {'state': 'IL', 'winner': 'Biden'},
#     'IN': {'state': 'IN', 'winner': 'Trump'},
#     'KS': {'state': 'KS', 'winner': 'Trump'},
#     'KY': {'state': 'KY', 'winner': 'Trump'},
#     'LA': {'state': 'LA', 'winner': 'Trump'},
#     'MA': {'state': 'MA', 'winner': 'Biden'},
#     'MD': {'state': 'MD', 'winner': 'Biden'},
#     'ME': {'state': 'ME', 'winner': 'Biden'},
#     'ME1': {'state': 'ME1', 'winner': 'Biden'},
#     'ME2': {'state': 'ME2', 'winner': 'Trump'},
#     'MI': {'state': 'MI', 'winner': 'Biden'},
#     'MN': {'state': 'MN', 'winner': 'Biden'},
#     'MO': {'state': 'MO', 'winner': 'Trump'},
#     'MS': {'state': 'MS', 'winner': 'Trump'},
#     'MT': {'state': 'MT', 'winner': 'Biden'},
#     'NC': {'state': 'NC', 'winner': 'Trump'},
#     'ND': {'state': 'ND', 'winner': 'Trump'},
#     'NE': {'state': 'NE', 'winner': 'Trump'},
#     'NE1': {'state': 'NE1', 'winner': 'Trump'},
#     'NE2': {'state': 'NE2', 'winner': 'Biden'},
#     'NE3': {'state': 'NE3', 'winner': 'Trump'},
#     'NH': {'state': 'NH', 'winner': 'Biden'},
#     'NJ': {'state': 'NJ', 'winner': 'Biden'},
#     'NM': {'state': 'NM', 'winner': 'Biden'},
#     'NV': {'state': 'NV', 'winner': 'Biden'},
#     'NY': {'state': 'NY', 'winner': 'Biden'},
#     'OH': {'state': 'OH', 'winner': 'Trump'},
#     'OK': {'state': 'OK', 'winner': 'Trump'},
#     'OR': {'state': 'OR', 'winner': 'Biden'},
#     'PA': {'state': 'PA', 'winner': 'Biden'},
#     'RI': {'state': 'RI', 'winner': 'Biden'},
#     'SC': {'state': 'SC', 'winner': 'Trump'},
#     'SD': {'state': 'SD', 'winner': 'Trump'},
#     'TN': {'state': 'TN', 'winner': 'Trump'},
#     'TX': {'state': 'TX', 'winner': 'Trump'},
#     'UT': {'state': 'UT', 'winner': 'Biden'},
#     'VA': {'state': 'VA', 'winner': 'Biden'},
#     'VT': {'state': 'VT', 'winner': 'Biden'},
#     'WA': {'state': 'WA', 'winner': 'Biden'},
#     'WI': {'state': 'WI', 'winner': 'Biden'},
#     'WV': {'state': 'WV', 'winner': 'Trump'},
#     'WY': {'state': 'WY', 'winner': 'Trump'}}},
#   {'winner': 'Biden',
#    'evs': {'Biden': 451, 'Trump': 87},
#    'states': {'AK': {'state': 'AK', 'winner': 'Biden'},
#     'AL': {'state': 'AL', 'winner': 'Trump'},
#     'AR': {'state': 'AR', 'winner': 'Trump'},
#     'AZ': {'state': 'AZ', 'winner': 'Biden'},
#     'CA': {'state': 'CA', 'winner': 'Biden'},
#     'CO': {'state': 'CO', 'winner': 'Biden'},
#     'CT': {'state': 'CT', 'winner': 'Biden'},
#     'DC': {'state': 'DC', 'winner': 'Biden'},
#     'DE': {'state': 'DE', 'winner': 'Biden'},
#     'FL': {'state': 'FL', 'winner': 'Biden'},
#     'GA': {'state': 'GA', 'winner': 'Biden'},
#     'HI': {'state': 'HI', 'winner': 'Biden'},
#     'IA': {'state': 'IA', 'winner': 'Biden'},
#     'ID': {'state': 'ID', 'winner': 'Trump'},
#     'IL': {'state': 'IL', 'winner': 'Biden'},
#     'IN': {'state': 'IN', 'winner': 'Trump'},
#     'KS': {'state': 'KS', 'winner': 'Trump'},
#     'KY': {'state': 'KY', 'winner': 'Trump'},
#     'LA': {'state': 'LA', 'winner': 'Biden'},
#     'MA': {'state': 'MA', 'winner': 'Biden'},
#     'MD': {'state': 'MD', 'winner': 'Biden'},
#     'ME': {'state': 'ME', 'winner': 'Biden'},
#     'ME1': {'state': 'ME1', 'winner': 'Biden'},
#     'ME2': {'state': 'ME2', 'winner': 'Biden'},
#     'MI': {'state': 'MI', 'winner': 'Biden'},
#     'MN': {'state': 'MN', 'winner': 'Biden'},
#     'MO': {'state': 'MO', 'winner': 'Biden'},
#     'MS': {'state': 'MS', 'winner': 'Biden'},
#     'MT': {'state': 'MT', 'winner': 'Biden'},
#     'NC': {'state': 'NC', 'winner': 'Biden'},
#     'ND': {'state': 'ND', 'winner': 'Trump'},
#     'NE': {'state': 'NE', 'winner': 'Trump'},
#     'NE1': {'state': 'NE1', 'winner': 'Trump'},
#     'NE2': {'state': 'NE2', 'winner': 'Trump'},
#     'NE3': {'state': 'NE3', 'winner': 'Trump'},
#     'NH': {'state': 'NH', 'winner': 'Biden'},
#     'NJ': {'state': 'NJ', 'winner': 'Biden'},
#     'NM': {'state': 'NM', 'winner': 'Biden'},
#     'NV': {'state': 'NV', 'winner': 'Biden'},
#     'NY': {'state': 'NY', 'winner': 'Biden'},
#     'OH': {'state': 'OH', 'winner': 'Biden'},
#     'OK': {'state': 'OK', 'winner': 'Trump'},
#     'OR': {'state': 'OR', 'winner': 'Biden'},
#     'PA': {'state': 'PA', 'winner': 'Biden'},
#     'RI': {'state': 'RI', 'winner': 'Biden'},
#     'SC': {'state': 'SC', 'winner': 'Biden'},
#     'SD': {'state': 'SD', 'winner': 'Trump'},
#     'TN': {'state': 'TN', 'winner': 'Trump'},
#     'TX': {'state': 'TX', 'winner': 'Biden'},
#     'UT': {'state': 'UT', 'winner': 'Trump'},
#     'VA': {'state': 'VA', 'winner': 'Biden'},
#     'VT': {'state': 'VT', 'winner': 'Biden'},
#     'WA': {'state': 'WA', 'winner': 'Biden'},
#     'WI': {'state': 'WI', 'winner': 'Biden'},
#     'WV': {'state': 'WV', 'winner': 'Trump'},
#     'WY': {'state': 'WY', 'winner': 'Trump'}}},
#   {'winner': 'Biden',
#    'evs': {'Biden': 318, 'Trump': 220},
#    'states': {'AK': {'state': 'AK', 'winner': 'Biden'},
#     'AL': {'state': 'AL', 'winner': 'Trump'},
#     'AR': {'state': 'AR', 'winner': 'Trump'},
#     'AZ': {'state': 'AZ', 'winner': 'Biden'},
#     'CA': {'state': 'CA', 'winner': 'Biden'},
#     'CO': {'state': 'CO', 'winner': 'Biden'},
#     'CT': {'state': 'CT', 'winner': 'Biden'},
#     'DC': {'state': 'DC', 'winner': 'Biden'},
#     'DE': {'state': 'DE', 'winner': 'Biden'},
#     'FL': {'state': 'FL', 'winner': 'Biden'},
#     'GA': {'state': 'GA', 'winner': 'Trump'},
#     'HI': {'state': 'HI', 'winner': 'Biden'},
#     'IA': {'state': 'IA', 'winner': 'Trump'},
#     'ID': {'state': 'ID', 'winner': 'Trump'},
#     'IL': {'state': 'IL', 'winner': 'Biden'},
#     'IN': {'state': 'IN', 'winner': 'Trump'},
#     'KS': {'state': 'KS', 'winner': 'Trump'},
#     'KY': {'state': 'KY', 'winner': 'Trump'},
#     'LA': {'state': 'LA', 'winner': 'Trump'},
#     'MA': {'state': 'MA', 'winner': 'Biden'},
#     'MD': {'state': 'MD', 'winner': 'Biden'},
#     'ME': {'state': 'ME', 'winner': 'Biden'},
#     'ME1': {'state': 'ME1', 'winner': 'Biden'},
#     'ME2': {'state': 'ME2', 'winner': 'Trump'},
#     'MI': {'state': 'MI', 'winner': 'Biden'},
#     'MN': {'state': 'MN', 'winner': 'Biden'},
#     'MO': {'state': 'MO', 'winner': 'Trump'},
#     'MS': {'state': 'MS', 'winner': 'Trump'},
#     'MT': {'state': 'MT', 'winner': 'Trump'},
#     'NC': {'state': 'NC', 'winner': 'Trump'},
#     'ND': {'state': 'ND', 'winner': 'Trump'},
#     'NE': {'state': 'NE', 'winner': 'Trump'},
#     'NE1': {'state': 'NE1', 'winner': 'Trump'},
#     'NE2': {'state': 'NE2', 'winner': 'Biden'},
#     'NE3': {'state': 'NE3', 'winner': 'Trump'},
#     'NH': {'state': 'NH', 'winner': 'Trump'},
#     'NJ': {'state': 'NJ', 'winner': 'Biden'},
#     'NM': {'state': 'NM', 'winner': 'Biden'},
#     'NV': {'state': 'NV', 'winner': 'Biden'},
#     'NY': {'state': 'NY', 'winner': 'Biden'},
#     'OH': {'state': 'OH', 'winner': 'Trump'},
#     'OK': {'state': 'OK', 'winner': 'Trump'},
#     'OR': {'state': 'OR', 'winner': 'Biden'},
#     'PA': {'state': 'PA', 'winner': 'Biden'},
#     'RI': {'state': 'RI', 'winner': 'Biden'},
#     'SC': {'state': 'SC', 'winner': 'Trump'},
#     'SD': {'state': 'SD', 'winner': 'Trump'},
#     'TN': {'state': 'TN', 'winner': 'Trump'},
#     'TX': {'state': 'TX', 'winner': 'Trump'},
#     'UT': {'state': 'UT', 'winner': 'Trump'},
#     'VA': {'state': 'VA', 'winner': 'Biden'},
#     'VT': {'state': 'VT', 'winner': 'Biden'},
#     'WA': {'state': 'WA', 'winner': 'Biden'},
#     'WI': {'state': 'WI', 'winner': 'Biden'},
#     'WV': {'state': 'WV', 'winner': 'Trump'},
#     'WY': {'state': 'WY', 'winner': 'Trump'}}},
#   {'winner': 'Biden',
#    'evs': {'Biden': 417, 'Trump': 121},
#    'states': {'AK': {'state': 'AK', 'winner': 'Trump'},
#     'AL': {'state': 'AL', 'winner': 'Trump'},
#     'AR': {'state': 'AR', 'winner': 'Trump'},
#     'AZ': {'state': 'AZ', 'winner': 'Trump'},
#     'CA': {'state': 'CA', 'winner': 'Biden'},
#     'CO': {'state': 'CO', 'winner': 'Biden'},
#     'CT': {'state': 'CT', 'winner': 'Biden'},
#     'DC': {'state': 'DC', 'winner': 'Biden'},
#     'DE': {'state': 'DE', 'winner': 'Biden'},
#     'FL': {'state': 'FL', 'winner': 'Biden'},
#     'GA': {'state': 'GA', 'winner': 'Biden'},
#     'HI': {'state': 'HI', 'winner': 'Biden'},
#     'IA': {'state': 'IA', 'winner': 'Trump'},
#     'ID': {'state': 'ID', 'winner': 'Trump'},
#     'IL': {'state': 'IL', 'winner': 'Biden'},
#     'IN': {'state': 'IN', 'winner': 'Biden'},
#     'KS': {'state': 'KS', 'winner': 'Trump'},
#     'KY': {'state': 'KY', 'winner': 'Trump'},
#     'LA': {'state': 'LA', 'winner': 'Trump'},
#     'MA': {'state': 'MA', 'winner': 'Biden'},
#     'MD': {'state': 'MD', 'winner': 'Biden'},
#     'ME': {'state': 'ME', 'winner': 'Biden'},
#     'ME1': {'state': 'ME1', 'winner': 'Biden'},
#     'ME2': {'state': 'ME2', 'winner': 'Biden'},
#     'MI': {'state': 'MI', 'winner': 'Biden'},
#     'MN': {'state': 'MN', 'winner': 'Biden'},
#     'MO': {'state': 'MO', 'winner': 'Biden'},
#     'MS': {'state': 'MS', 'winner': 'Trump'},
#     'MT': {'state': 'MT', 'winner': 'Trump'},
#     'NC': {'state': 'NC', 'winner': 'Biden'},
#     'ND': {'state': 'ND', 'winner': 'Trump'},
#     'NE': {'state': 'NE', 'winner': 'Trump'},
#     'NE1': {'state': 'NE1', 'winner': 'Trump'},
#     'NE2': {'state': 'NE2', 'winner': 'Biden'},
#     'NE3': {'state': 'NE3', 'winner': 'Trump'},
#     'NH': {'state': 'NH', 'winner': 'Biden'},
#     'NJ': {'state': 'NJ', 'winner': 'Biden'},
#     'NM': {'state': 'NM', 'winner': 'Biden'},
#     'NV': {'state': 'NV', 'winner': 'Biden'},
#     'NY': {'state': 'NY', 'winner': 'Biden'},
#     'OH': {'state': 'OH', 'winner': 'Biden'},
#     'OK': {'state': 'OK', 'winner': 'Trump'},
#     'OR': {'state': 'OR', 'winner': 'Biden'},
#     'PA': {'state': 'PA', 'winner': 'Biden'},
#     'RI': {'state': 'RI', 'winner': 'Biden'},
#     'SC': {'state': 'SC', 'winner': 'Trump'},
#     'SD': {'state': 'SD', 'winner': 'Trump'},
#     'TN': {'state': 'TN', 'winner': 'Trump'},
#     'TX': {'state': 'TX', 'winner': 'Biden'},
#     'UT': {'state': 'UT', 'winner': 'Trump'},
#     'VA': {'state': 'VA', 'winner': 'Biden'},
#     'VT': {'state': 'VT', 'winner': 'Biden'},
#     'WA': {'state': 'WA', 'winner': 'Biden'},
#     'WI': {'state': 'WI', 'winner': 'Biden'},
#     'WV': {'state': 'WV', 'winner': 'Trump'},
#     'WY': {'state': 'WY', 'winner': 'Trump'}}},
#   {'winner': 'Biden',
#    'evs': {'Biden': 388, 'Trump': 150},
#    'states': {'AK': {'state': 'AK', 'winner': 'Trump'},
#     'AL': {'state': 'AL', 'winner': 'Trump'},
#     'AR': {'state': 'AR', 'winner': 'Trump'},
#     'AZ': {'state': 'AZ', 'winner': 'Biden'},
#     'CA': {'state': 'CA', 'winner': 'Biden'},
#     'CO': {'state': 'CO', 'winner': 'Biden'},
#     'CT': {'state': 'CT', 'winner': 'Biden'},
#     'DC': {'state': 'DC', 'winner': 'Biden'},
#     'DE': {'state': 'DE', 'winner': 'Biden'},
#     'FL': {'state': 'FL', 'winner': 'Biden'},
#     'GA': {'state': 'GA', 'winner': 'Biden'},
#     'HI': {'state': 'HI', 'winner': 'Biden'},
#     'IA': {'state': 'IA', 'winner': 'Trump'},
#     'ID': {'state': 'ID', 'winner': 'Trump'},
#     'IL': {'state': 'IL', 'winner': 'Biden'},
#     'IN': {'state': 'IN', 'winner': 'Trump'},
#     'KS': {'state': 'KS', 'winner': 'Trump'},
#     'KY': {'state': 'KY', 'winner': 'Trump'},
#     'LA': {'state': 'LA', 'winner': 'Trump'},
#     'MA': {'state': 'MA', 'winner': 'Biden'},
#     'MD': {'state': 'MD', 'winner': 'Biden'},
#     'ME': {'state': 'ME', 'winner': 'Biden'},
#     'ME1': {'state': 'ME1', 'winner': 'Biden'},
#     'ME2': {'state': 'ME2', 'winner': 'Trump'},
#     'MI': {'state': 'MI', 'winner': 'Biden'},
#     'MN': {'state': 'MN', 'winner': 'Biden'},
#     'MO': {'state': 'MO', 'winner': 'Trump'},
#     'MS': {'state': 'MS', 'winner': 'Trump'},
#     'MT': {'state': 'MT', 'winner': 'Trump'},
#     'NC': {'state': 'NC', 'winner': 'Biden'},
#     'ND': {'state': 'ND', 'winner': 'Trump'},
#     'NE': {'state': 'NE', 'winner': 'Trump'},
#     'NE1': {'state': 'NE1', 'winner': 'Trump'},
#     'NE2': {'state': 'NE2', 'winner': 'Biden'},
#     'NE3': {'state': 'NE3', 'winner': 'Trump'},
#     'NH': {'state': 'NH', 'winner': 'Biden'},
#     'NJ': {'state': 'NJ', 'winner': 'Biden'},
#     'NM': {'state': 'NM', 'winner': 'Biden'},
#     'NV': {'state': 'NV', 'winner': 'Biden'},
#     'NY': {'state': 'NY', 'winner': 'Biden'},
#     'OH': {'state': 'OH', 'winner': 'Trump'},
#     'OK': {'state': 'OK', 'winner': 'Trump'},
#     'OR': {'state': 'OR', 'winner': 'Biden'},
#     'PA': {'state': 'PA', 'winner': 'Biden'},
#     'RI': {'state': 'RI', 'winner': 'Biden'},
#     'SC': {'state': 'SC', 'winner': 'Trump'},
#     'SD': {'state': 'SD', 'winner': 'Trump'},
#     'TN': {'state': 'TN', 'winner': 'Trump'},
#     'TX': {'state': 'TX', 'winner': 'Biden'},
#     'UT': {'state': 'UT', 'winner': 'Trump'},
#     'VA': {'state': 'VA', 'winner': 'Biden'},
#     'VT': {'state': 'VT', 'winner': 'Biden'},
#     'WA': {'state': 'WA', 'winner': 'Biden'},
#     'WI': {'state': 'WI', 'winner': 'Biden'},
#     'WV': {'state': 'WV', 'winner': 'Trump'},
#     'WY': {'state': 'WY', 'winner': 'Trump'}}},
#   {'winner': 'Biden',
#    'evs': {'Biden': 350, 'Trump': 188},
# ...
#   {'winner': 'Biden',
#    'evs': {'Biden': 390, 'Trump': 148},
#    'states': {'AK': {'state': 'AK', 'winner': 'Biden'},
#     'AL': {'state': 'AL', 'winner': 'Trump'},
#     'AR': {'state': 'AR', 'winner': 'Trump'},
#     'AZ': {'state': 'AZ', 'winner': 'Biden'},
#     'CA': {'state': 'CA', 'winner': 'Biden'},
#     'CO': {'state': 'CO', 'winner': 'Biden'},
#     'CT': {'state': 'CT', 'winner': 'Biden'},
#     'DC': {'state': 'DC', 'winner': 'Biden'},
#     'DE': {'state': 'DE', 'winner': 'Biden'},
#     'FL': {'state': 'FL', 'winner': 'Biden'},
#     'GA': {'state': 'GA', 'winner': 'Biden'},
#     'HI': {'state': 'HI', 'winner': 'Biden'},
#     'IA': {'state': 'IA', 'winner': 'Biden'},
#     'ID': {'state': 'ID', 'winner': 'Trump'},
#     'IL': {'state': 'IL', 'winner': 'Biden'},
#     'IN': {'state': 'IN', 'winner': 'Trump'},
#     'KS': {'state': 'KS', 'winner': 'Trump'},
#     'KY': {'state': 'KY', 'winner': 'Trump'},
#     'LA': {'state': 'LA', 'winner': 'Trump'},
#     'MA': {'state': 'MA', 'winner': 'Biden'},
#     'MD': {'state': 'MD', 'winner': 'Biden'},
#     'ME': {'state': 'ME', 'winner': 'Biden'},
#     'ME1': {'state': 'ME1', 'winner': 'Biden'},
#     'ME2': {'state': 'ME2', 'winner': 'Biden'},
#     'MI': {'state': 'MI', 'winner': 'Biden'},
#     'MN': {'state': 'MN', 'winner': 'Biden'},
#     'MO': {'state': 'MO', 'winner': 'Trump'},
#     'MS': {'state': 'MS', 'winner': 'Trump'},
#     'MT': {'state': 'MT', 'winner': 'Biden'},
#     'NC': {'state': 'NC', 'winner': 'Biden'},
#     'ND': {'state': 'ND', 'winner': 'Trump'},
#     'NE': {'state': 'NE', 'winner': 'Trump'},
#     'NE1': {'state': 'NE1', 'winner': 'Trump'},
#     'NE2': {'state': 'NE2', 'winner': 'Biden'},
#     'NE3': {'state': 'NE3', 'winner': 'Trump'},
#     'NH': {'state': 'NH', 'winner': 'Biden'},
#     'NJ': {'state': 'NJ', 'winner': 'Biden'},
#     'NM': {'state': 'NM', 'winner': 'Biden'},
#     'NV': {'state': 'NV', 'winner': 'Biden'},
#     'NY': {'state': 'NY', 'winner': 'Biden'},
#     'OH': {'state': 'OH', 'winner': 'Biden'},
#     'OK': {'state': 'OK', 'winner': 'Trump'},
#     'OR': {'state': 'OR', 'winner': 'Biden'},
#     'PA': {'state': 'PA', 'winner': 'Biden'},
#     'RI': {'state': 'RI', 'winner': 'Biden'},
#     'SC': {'state': 'SC', 'winner': 'Biden'},
#     'SD': {'state': 'SD', 'winner': 'Trump'},
#     'TN': {'state': 'TN', 'winner': 'Trump'},
#     'TX': {'state': 'TX', 'winner': 'Trump'},
#     'UT': {'state': 'UT', 'winner': 'Trump'},
#     'VA': {'state': 'VA', 'winner': 'Biden'},
#     'VT': {'state': 'VT', 'winner': 'Biden'},
#     'WA': {'state': 'WA', 'winner': 'Biden'},
#     'WI': {'state': 'WI', 'winner': 'Biden'},
#     'WV': {'state': 'WV', 'winner': 'Trump'},
#     'WY': {'state': 'WY', 'winner': 'Trump'}}},
#   {'winner': 'Biden',
#    'evs': {'Biden': 334, 'Trump': 204},
#    'states': {'AK': {'state': 'AK', 'winner': 'Trump'},
#     'AL': {'state': 'AL', 'winner': 'Trump'},
#     'AR': {'state': 'AR', 'winner': 'Trump'},
#     'AZ': {'state': 'AZ', 'winner': 'Biden'},
#     'CA': {'state': 'CA', 'winner': 'Biden'},
#     'CO': {'state': 'CO', 'winner': 'Biden'},
#     'CT': {'state': 'CT', 'winner': 'Biden'},
#     'DC': {'state': 'DC', 'winner': 'Biden'},
#     'DE': {'state': 'DE', 'winner': 'Biden'},
#     'FL': {'state': 'FL', 'winner': 'Biden'},
#     'GA': {'state': 'GA', 'winner': 'Trump'},
#     'HI': {'state': 'HI', 'winner': 'Biden'},
#     'IA': {'state': 'IA', 'winner': 'Trump'},
#     'ID': {'state': 'ID', 'winner': 'Trump'},
#     'IL': {'state': 'IL', 'winner': 'Biden'},
#     'IN': {'state': 'IN', 'winner': 'Trump'},
#     'KS': {'state': 'KS', 'winner': 'Trump'},
#     'KY': {'state': 'KY', 'winner': 'Trump'},
#     'LA': {'state': 'LA', 'winner': 'Trump'},
#     'MA': {'state': 'MA', 'winner': 'Biden'},
#     'MD': {'state': 'MD', 'winner': 'Biden'},
#     'ME': {'state': 'ME', 'winner': 'Biden'},
#     'ME1': {'state': 'ME1', 'winner': 'Biden'},
#     'ME2': {'state': 'ME2', 'winner': 'Biden'},
#     'MI': {'state': 'MI', 'winner': 'Biden'},
#     'MN': {'state': 'MN', 'winner': 'Biden'},
#     'MO': {'state': 'MO', 'winner': 'Trump'},
#     'MS': {'state': 'MS', 'winner': 'Trump'},
#     'MT': {'state': 'MT', 'winner': 'Trump'},
#     'NC': {'state': 'NC', 'winner': 'Biden'},
#     'ND': {'state': 'ND', 'winner': 'Trump'},
#     'NE': {'state': 'NE', 'winner': 'Trump'},
#     'NE1': {'state': 'NE1', 'winner': 'Trump'},
#     'NE2': {'state': 'NE2', 'winner': 'Trump'},
#     'NE3': {'state': 'NE3', 'winner': 'Trump'},
#     'NH': {'state': 'NH', 'winner': 'Biden'},
#     'NJ': {'state': 'NJ', 'winner': 'Biden'},
#     'NM': {'state': 'NM', 'winner': 'Biden'},
#     'NV': {'state': 'NV', 'winner': 'Biden'},
#     'NY': {'state': 'NY', 'winner': 'Biden'},
#     'OH': {'state': 'OH', 'winner': 'Trump'},
#     'OK': {'state': 'OK', 'winner': 'Trump'},
#     'OR': {'state': 'OR', 'winner': 'Biden'},
#     'PA': {'state': 'PA', 'winner': 'Biden'},
#     'RI': {'state': 'RI', 'winner': 'Biden'},
#     'SC': {'state': 'SC', 'winner': 'Trump'},
#     'SD': {'state': 'SD', 'winner': 'Trump'},
#     'TN': {'state': 'TN', 'winner': 'Trump'},
#     'TX': {'state': 'TX', 'winner': 'Trump'},
#     'UT': {'state': 'UT', 'winner': 'Trump'},
#     'VA': {'state': 'VA', 'winner': 'Biden'},
#     'VT': {'state': 'VT', 'winner': 'Biden'},
#     'WA': {'state': 'WA', 'winner': 'Biden'},
#     'WI': {'state': 'WI', 'winner': 'Biden'},
#     'WV': {'state': 'WV', 'winner': 'Trump'},
#     'WY': {'state': 'WY', 'winner': 'Trump'}}},
#   {'winner': 'Biden',
#    'evs': {'Biden': 330, 'Trump': 208},
#    'states': {'AK': {'state': 'AK', 'winner': 'Trump'},
#     'AL': {'state': 'AL', 'winner': 'Trump'},
#     'AR': {'state': 'AR', 'winner': 'Trump'},
#     'AZ': {'state': 'AZ', 'winner': 'Biden'},
#     'CA': {'state': 'CA', 'winner': 'Biden'},
#     'CO': {'state': 'CO', 'winner': 'Trump'},
#     'CT': {'state': 'CT', 'winner': 'Biden'},
#     'DC': {'state': 'DC', 'winner': 'Biden'},
#     'DE': {'state': 'DE', 'winner': 'Biden'},
#     'FL': {'state': 'FL', 'winner': 'Biden'},
#     'GA': {'state': 'GA', 'winner': 'Biden'},
#     'HI': {'state': 'HI', 'winner': 'Biden'},
#     'IA': {'state': 'IA', 'winner': 'Trump'},
#     'ID': {'state': 'ID', 'winner': 'Trump'},
#     'IL': {'state': 'IL', 'winner': 'Biden'},
#     'IN': {'state': 'IN', 'winner': 'Trump'},
#     'KS': {'state': 'KS', 'winner': 'Trump'},
#     'KY': {'state': 'KY', 'winner': 'Trump'},
#     'LA': {'state': 'LA', 'winner': 'Trump'},
#     'MA': {'state': 'MA', 'winner': 'Biden'},
#     'MD': {'state': 'MD', 'winner': 'Biden'},
#     'ME': {'state': 'ME', 'winner': 'Trump'},
#     'ME1': {'state': 'ME1', 'winner': 'Biden'},
#     'ME2': {'state': 'ME2', 'winner': 'Trump'},
#     'MI': {'state': 'MI', 'winner': 'Biden'},
#     'MN': {'state': 'MN', 'winner': 'Trump'},
#     'MO': {'state': 'MO', 'winner': 'Trump'},
#     'MS': {'state': 'MS', 'winner': 'Biden'},
#     'MT': {'state': 'MT', 'winner': 'Trump'},
#     'NC': {'state': 'NC', 'winner': 'Biden'},
#     'ND': {'state': 'ND', 'winner': 'Trump'},
#     'NE': {'state': 'NE', 'winner': 'Trump'},
#     'NE1': {'state': 'NE1', 'winner': 'Trump'},
#     'NE2': {'state': 'NE2', 'winner': 'Trump'},
#     'NE3': {'state': 'NE3', 'winner': 'Trump'},
#     'NH': {'state': 'NH', 'winner': 'Trump'},
#     'NJ': {'state': 'NJ', 'winner': 'Biden'},
#     'NM': {'state': 'NM', 'winner': 'Biden'},
#     'NV': {'state': 'NV', 'winner': 'Biden'},
#     'NY': {'state': 'NY', 'winner': 'Biden'},
#     'OH': {'state': 'OH', 'winner': 'Trump'},
#     'OK': {'state': 'OK', 'winner': 'Trump'},
#     'OR': {'state': 'OR', 'winner': 'Biden'},
#     'PA': {'state': 'PA', 'winner': 'Biden'},
#     'RI': {'state': 'RI', 'winner': 'Biden'},
#     'SC': {'state': 'SC', 'winner': 'Trump'},
#     'SD': {'state': 'SD', 'winner': 'Trump'},
#     'TN': {'state': 'TN', 'winner': 'Trump'},
#     'TX': {'state': 'TX', 'winner': 'Trump'},
#     'UT': {'state': 'UT', 'winner': 'Trump'},
#     'VA': {'state': 'VA', 'winner': 'Biden'},
#     'VT': {'state': 'VT', 'winner': 'Biden'},
#     'WA': {'state': 'WA', 'winner': 'Biden'},
#     'WI': {'state': 'WI', 'winner': 'Biden'},
#     'WV': {'state': 'WV', 'winner': 'Trump'},
#     'WY': {'state': 'WY', 'winner': 'Trump'}}},
#   {'winner': 'Biden',
#    'evs': {'Biden': 416, 'Trump': 122},
#    'states': {'AK': {'state': 'AK', 'winner': 'Biden'},
#     'AL': {'state': 'AL', 'winner': 'Trump'},
#     'AR': {'state': 'AR', 'winner': 'Trump'},
#     'AZ': {'state': 'AZ', 'winner': 'Biden'},
#     'CA': {'state': 'CA', 'winner': 'Biden'},
#     'CO': {'state': 'CO', 'winner': 'Biden'},
#     'CT': {'state': 'CT', 'winner': 'Biden'},
#     'DC': {'state': 'DC', 'winner': 'Biden'},
#     'DE': {'state': 'DE', 'winner': 'Biden'},
#     'FL': {'state': 'FL', 'winner': 'Biden'},
#     'GA': {'state': 'GA', 'winner': 'Biden'},
#     'HI': {'state': 'HI', 'winner': 'Biden'},
#     'IA': {'state': 'IA', 'winner': 'Biden'},
#     'ID': {'state': 'ID', 'winner': 'Trump'},
#     'IL': {'state': 'IL', 'winner': 'Biden'},
#     'IN': {'state': 'IN', 'winner': 'Trump'},
#     'KS': {'state': 'KS', 'winner': 'Trump'},
#     'KY': {'state': 'KY', 'winner': 'Trump'},
#     'LA': {'state': 'LA', 'winner': 'Trump'},
#     'MA': {'state': 'MA', 'winner': 'Biden'},
#     'MD': {'state': 'MD', 'winner': 'Biden'},
#     'ME': {'state': 'ME', 'winner': 'Biden'},
#     'ME1': {'state': 'ME1', 'winner': 'Biden'},
#     'ME2': {'state': 'ME2', 'winner': 'Biden'},
#     'MI': {'state': 'MI', 'winner': 'Biden'},
#     'MN': {'state': 'MN', 'winner': 'Biden'},
#     'MO': {'state': 'MO', 'winner': 'Trump'},
#     'MS': {'state': 'MS', 'winner': 'Trump'},
#     'MT': {'state': 'MT', 'winner': 'Trump'},
#     'NC': {'state': 'NC', 'winner': 'Biden'},
#     'ND': {'state': 'ND', 'winner': 'Trump'},
#     'NE': {'state': 'NE', 'winner': 'Trump'},
#     'NE1': {'state': 'NE1', 'winner': 'Trump'},
#     'NE2': {'state': 'NE2', 'winner': 'Biden'},
#     'NE3': {'state': 'NE3', 'winner': 'Trump'},
#     'NH': {'state': 'NH', 'winner': 'Biden'},
#     'NJ': {'state': 'NJ', 'winner': 'Biden'},
#     'NM': {'state': 'NM', 'winner': 'Biden'},
#     'NV': {'state': 'NV', 'winner': 'Biden'},
#     'NY': {'state': 'NY', 'winner': 'Biden'},
#     'OH': {'state': 'OH', 'winner': 'Biden'},
#     'OK': {'state': 'OK', 'winner': 'Trump'},
#     'OR': {'state': 'OR', 'winner': 'Biden'},
#     'PA': {'state': 'PA', 'winner': 'Biden'},
#     'RI': {'state': 'RI', 'winner': 'Biden'},
#     'SC': {'state': 'SC', 'winner': 'Trump'},
#     'SD': {'state': 'SD', 'winner': 'Trump'},
#     'TN': {'state': 'TN', 'winner': 'Trump'},
#     'TX': {'state': 'TX', 'winner': 'Biden'},
#     'UT': {'state': 'UT', 'winner': 'Trump'},
#     'VA': {'state': 'VA', 'winner': 'Biden'},
#     'VT': {'state': 'VT', 'winner': 'Biden'},
#     'WA': {'state': 'WA', 'winner': 'Biden'},
#     'WI': {'state': 'WI', 'winner': 'Biden'},
#     'WV': {'state': 'WV', 'winner': 'Trump'},
#     'WY': {'state': 'WY', 'winner': 'Trump'}}},
#   {'winner': 'Biden',
#    'evs': {'Biden': 395, 'Trump': 143},
#    'states': {'AK': {'state': 'AK', 'winner': 'Trump'},
#     'AL': {'state': 'AL', 'winner': 'Trump'},
#     'AR': {'state': 'AR', 'winner': 'Trump'},
#     'AZ': {'state': 'AZ', 'winner': 'Trump'},
#     'CA': {'state': 'CA', 'winner': 'Biden'},
#     'CO': {'state': 'CO', 'winner': 'Biden'},
#     'CT': {'state': 'CT', 'winner': 'Biden'},
#     'DC': {'state': 'DC', 'winner': 'Biden'},
#     'DE': {'state': 'DE', 'winner': 'Biden'},
#     'FL': {'state': 'FL', 'winner': 'Biden'},
#     'GA': {'state': 'GA', 'winner': 'Biden'},
#     'HI': {'state': 'HI', 'winner': 'Biden'},
#     'IA': {'state': 'IA', 'winner': 'Trump'},
#     'ID': {'state': 'ID', 'winner': 'Trump'},
#     'IL': {'state': 'IL', 'winner': 'Biden'},
#     'IN': {'state': 'IN', 'winner': 'Trump'},
#     'KS': {'state': 'KS', 'winner': 'Trump'},
#     'KY': {'state': 'KY', 'winner': 'Trump'},
#     'LA': {'state': 'LA', 'winner': 'Trump'},
#     'MA': {'state': 'MA', 'winner': 'Biden'},
#     'MD': {'state': 'MD', 'winner': 'Biden'},
#     'ME': {'state': 'ME', 'winner': 'Biden'},
#     'ME1': {'state': 'ME1', 'winner': 'Biden'},
#     'ME2': {'state': 'ME2', 'winner': 'Trump'},
#     'MI': {'state': 'MI', 'winner': 'Biden'},
#     'MN': {'state': 'MN', 'winner': 'Biden'},
#     'MO': {'state': 'MO', 'winner': 'Trump'},
#     'MS': {'state': 'MS', 'winner': 'Trump'},
#     'MT': {'state': 'MT', 'winner': 'Trump'},
#     'NC': {'state': 'NC', 'winner': 'Biden'},
#     'ND': {'state': 'ND', 'winner': 'Trump'},
#     'NE': {'state': 'NE', 'winner': 'Trump'},
#     'NE1': {'state': 'NE1', 'winner': 'Trump'},
#     'NE2': {'state': 'NE2', 'winner': 'Biden'},
#     'NE3': {'state': 'NE3', 'winner': 'Trump'},
#     'NH': {'state': 'NH', 'winner': 'Biden'},
#     'NJ': {'state': 'NJ', 'winner': 'Biden'},
#     'NM': {'state': 'NM', 'winner': 'Biden'},
#     'NV': {'state': 'NV', 'winner': 'Biden'},
#     'NY': {'state': 'NY', 'winner': 'Biden'},
#     'OH': {'state': 'OH', 'winner': 'Biden'},
#     'OK': {'state': 'OK', 'winner': 'Trump'},
#     'OR': {'state': 'OR', 'winner': 'Biden'},
#     'PA': {'state': 'PA', 'winner': 'Biden'},
#     'RI': {'state': 'RI', 'winner': 'Biden'},
#     'SC': {'state': 'SC', 'winner': 'Trump'},
#     'SD': {'state': 'SD', 'winner': 'Trump'},
#     'TN': {'state': 'TN', 'winner': 'Trump'},
#     'TX': {'state': 'TX', 'winner': 'Biden'},
#     'UT': {'state': 'UT', 'winner': 'Trump'},
#     'VA': {'state': 'VA', 'winner': 'Biden'},
#     'VT': {'state': 'VT', 'winner': 'Biden'},
#     'WA': {'state': 'WA', 'winner': 'Biden'},
#     'WI': {'state': 'WI', 'winner': 'Biden'},
#     'WV': {'state': 'WV', 'winner': 'Trump'},
#     'WY': {'state': 'WY', 'winner': 'Trump'}}},
#   {'winner': 'Biden',
#    'evs': {'Biden': 318, 'Trump': 220},
#    'states': {'AK': {'state': 'AK', 'winner': 'Trump'},
#     'AL': {'state': 'AL', 'winner': 'Trump'},
#     'AR': {'state': 'AR', 'winner': 'Trump'},
#     'AZ': {'state': 'AZ', 'winner': 'Trump'},
#     'CA': {'state': 'CA', 'winner': 'Biden'},
#     'CO': {'state': 'CO', 'winner': 'Biden'},
#     'CT': {'state': 'CT', 'winner': 'Biden'},
#     'DC': {'state': 'DC', 'winner': 'Biden'},
#     'DE': {'state': 'DE', 'winner': 'Biden'},
#     'FL': {'state': 'FL', 'winner': 'Biden'},
#     'GA': {'state': 'GA', 'winner': 'Trump'},
#     'HI': {'state': 'HI', 'winner': 'Biden'},
#     'IA': {'state': 'IA', 'winner': 'Biden'},
#     'ID': {'state': 'ID', 'winner': 'Trump'},
#     'IL': {'state': 'IL', 'winner': 'Biden'},
#     'IN': {'state': 'IN', 'winner': 'Trump'},
#     'KS': {'state': 'KS', 'winner': 'Trump'},
#     'KY': {'state': 'KY', 'winner': 'Trump'},
#     'LA': {'state': 'LA', 'winner': 'Trump'},
#     'MA': {'state': 'MA', 'winner': 'Biden'},
#     'MD': {'state': 'MD', 'winner': 'Biden'},
#     'ME': {'state': 'ME', 'winner': 'Biden'},
#     'ME1': {'state': 'ME1', 'winner': 'Biden'},
#     'ME2': {'state': 'ME2', 'winner': 'Biden'},
#     'MI': {'state': 'MI', 'winner': 'Trump'},
#     'MN': {'state': 'MN', 'winner': 'Biden'},
#     'MO': {'state': 'MO', 'winner': 'Trump'},
#     'MS': {'state': 'MS', 'winner': 'Biden'},
#     'MT': {'state': 'MT', 'winner': 'Trump'},
#     'NC': {'state': 'NC', 'winner': 'Biden'},
#     'ND': {'state': 'ND', 'winner': 'Trump'},
#     'NE': {'state': 'NE', 'winner': 'Trump'},
#     'NE1': {'state': 'NE1', 'winner': 'Trump'},
#     'NE2': {'state': 'NE2', 'winner': 'Biden'},
#     'NE3': {'state': 'NE3', 'winner': 'Trump'},
#     'NH': {'state': 'NH', 'winner': 'Biden'},
#     'NJ': {'state': 'NJ', 'winner': 'Biden'},
#     'NM': {'state': 'NM', 'winner': 'Biden'},
#     'NV': {'state': 'NV', 'winner': 'Trump'},
#     'NY': {'state': 'NY', 'winner': 'Biden'},
#     'OH': {'state': 'OH', 'winner': 'Trump'},
#     'OK': {'state': 'OK', 'winner': 'Trump'},
#     'OR': {'state': 'OR', 'winner': 'Trump'},
#     'PA': {'state': 'PA', 'winner': 'Biden'},
#     'RI': {'state': 'RI', 'winner': 'Biden'},
#     'SC': {'state': 'SC', 'winner': 'Trump'},
#     'SD': {'state': 'SD', 'winner': 'Trump'},
#     'TN': {'state': 'TN', 'winner': 'Biden'},
#     'TX': {'state': 'TX', 'winner': 'Trump'},
#     'UT': {'state': 'UT', 'winner': 'Trump'},
#     'VA': {'state': 'VA', 'winner': 'Biden'},
#     'VT': {'state': 'VT', 'winner': 'Biden'},
#     'WA': {'state': 'WA', 'winner': 'Biden'},
#     'WI': {'state': 'WI', 'winner': 'Biden'},
#     'WV': {'state': 'WV', 'winner': 'Trump'},
#     'WY': {'state': 'WY', 'winner': 'Trump'}}}]}

# %%
d = {state:[] for state in state_abbrev}
d['overall'] = []

for simulation in us_simulations[0]['simulations']:
    for state in state_abbrev:
        d[state].append(int(simulation['states'][state]['winner']=='Biden'))
    d['overall'].append(int(simulation['winner']=='Biden'))

# %%
sim_outcomes = pd.DataFrame(data=d)

# %%
np.sum(sim_outcomes.overall)
# Out:
# 87

# %%
cov = {}

# https://stats.stackexchange.com/questions/67019/variance-and-covariance-of-binary-data/67218
for state_a in sim_outcomes.columns:
    for state_b in sim_outcomes.columns:
        k_ab = len(sim_outcomes[sim_outcomes[state_a] + sim_outcomes[state_b] == 2])
        k_a = np.sum(sim_outcomes[state_a])
        k_b = np.sum(sim_outcomes[state_b])
        cov[(state_a,state_b)] = (100*k_ab - k_a*k_b)/100**2

# %%
np.min([v for k,v in cov.items()])
# Out:
# -0.0097

# %%
cov_order = '''FL
overall
MI
PA
TX
NC
WI
MN
OH
IA
AZ
NV
GA
NH
NM
VA
NY
CT
DE
IL
CA
CO
OR
RI
WA
HI
MD
MA
NJ
VT
AK
WY
AL
AR
NE
ID
OK
KY
IN'''.split('\n')

# %%
l = []

for row_state in cov_order:
    row = []
    for col_state in cov_order:
        row.append(cov[(row_state,col_state)])
    l.append(row)

# %%
cov[('AL','AK')]
# Out:
# 0.0087

# %%
cov[('AK','AL')]
# Out:
# 0.0087

# %%
for state, values in cov.items():
    if cov[state[0],state[1]] != cov[state[1],state[0]]:
        print(state[0],state[1])

# %%
# for state in state_abbrev:
#     print(state, cov['overall',state])

# %%
all([cov[state[0],state[1]] == cov[state[1],state[0]]  for state, value in cov.items()])
# Out:
# True

# %%
cov_mat = np.array(l)

# %%
returns = '''0.46181
0.3595062
0.329469875
0.259193375
0.23264
0.218074325
0.19213875
0.18279825
0.166805
0.15296875
0.15036575
0.14933735
0.1424675
0.08453125
0.078919875
0.039495275
0.03387075
0.03237145
0.024974375
0.024154375
0.023231875
0.022885325
0.02186
0.018929
0.016108125
0.0158775
0.014670125
0.014467125
0.013135625
0.0120185
0.0098375
0.00886375
0.008679
0.008113125
0.007974125
0.00457125
0.003031
0.002939975
0.00114875'''

# %%
returns_list = [float(ret) for ret in returns.split('\n')]

# %%
len(returns_list)
# Out:
# 39

# %%
cov_mat.shape
# Out:
# (39, 39)

# %%
ef = EfficientFrontier(np.array(returns_list),cov_mat)
weights = ef.efficient_return(.3)

# %%
np.array_equal(cov_mat,cov_mat.T)
# Out:
# True

# %%
ef.portfolio_performance(verbose=True)
# Out:
# Expected annual return: 30.0%
# Annual volatility: 22.3%
# Sharpe Ratio: 1.26
# (0.3, 0.22297466822371337, 1.255748028377252)

# %%
w = [weights[i] for i in range(39)]
pd.DataFrame(data={'weight':w,'state':cov_order})
# Out:
#       weight    state
# 0   0.234803       FL
# 1   0.134715  overall
# 2   0.353035       MI
# 3   0.000000       PA
# 4   0.009649       TX
# 5   0.000000       NC
# 6   0.000000       WI
# 7   0.097688       MN
# 8   0.000000       OH
# 9   0.000000       IA
# 10  0.000000       AZ
# 11  0.000000       NV
# 12  0.000000       GA
# 13  0.000000       NH
# 14  0.000000       NM
# 15  0.170110       VA
# 16  0.000000       NY
# 17  0.000000       CT
# 18  0.000000       DE
# 19  0.000000       IL
# 20  0.000000       CA
# 21  0.000000       CO
# 22  0.000000       OR
# 23  0.000000       RI
# 24  0.000000       WA
# 25  0.000000       HI
# 26  0.000000       MD
# 27  0.000000       MA
# 28  0.000000       NJ
# 29  0.000000       VT
# 30  0.000000       AK
# 31  0.000000       WY
# 32  0.000000       AL
# 33  0.000000       AR
# 34  0.000000       NE
# 35  0.000000       ID
# 36  0.000000       OK
# 37  0.000000       KY
# 38  0.000000       IN

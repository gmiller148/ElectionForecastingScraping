# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
page = requests.get('https://www.bovada.lv/services/sports/event/coupon/events/A/description/politics?marketFilterId=rank&preMatchOnly=true&eventsLimit=50&lang=en')

# %%
json.loads(page.text)
# Out:
# [{'path': [{'id': '8875491',
#     'link': '/politics/us-politics/us-presidential-election-2020/election-main-markets',
#     'description': 'Election Main Markets',
#     'type': 'LEAGUE',
#     'sportCode': 'POLI',
#     'order': 1,
#     'leaf': True,
#     'current': False},
#    {'id': '4003088',
#     'link': '/politics/us-politics/us-presidential-election-2020',
#     'description': 'US Presidential Election 2020',
#     'type': 'CATEGORY',
#     'sportCode': 'POLI',
#     'order': 1,
#     'leaf': False,
#     'current': False},
#    {'id': '2606795',
#     'link': '/politics/us-politics',
#     'description': 'US Politics',
#     'type': 'CATEGORY',
#     'sportCode': 'POLI',
#     'order': 1,
#     'leaf': False,
#     'current': False},
#    {'id': '22888',
#     'link': '/politics',
#     'description': 'Politics',
#     'type': 'SPORT',
#     'sportCode': 'POLI',
#     'order': 6,
#     'leaf': False,
#     'current': True}],
#   'events': [{'id': '7408338',
# ...

# %%
soup = BeautifulSoup(page.text,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <link href="/assets/css/main-67f54068-dba0-450e-8c8e-4a267cba1320.css" rel="stylesheet" type="text/css"/>
#   <script>
# ...
